# %%
import pandas as pd
import random
from rapidfuzz import process, fuzz
import time
import numpy as np
from scipy.stats import mode
from sklearn.metrics import pairwise_distances
import spoa
from numba import njit, prange
from rapidfuzz import fuzz
from sklearn.cluster import AgglomerativeClustering
from scipy.cluster.hierarchy import dendrogram


# --- 2. DATA GENERATION & UTILS ---
def mutate_sequence(seq, error_rate=0.10):
    if error_rate <= 0:
        return seq

    seq_list = list(seq)
    new_seq = []
    for base in seq_list:
        if random.random() < error_rate:
            r = random.random()
            if r < 0.5:
                new_seq.append(random.choice("ACGT"))
            elif r < 0.75:
                new_seq.append(base)
                new_seq.append(random.choice("ACGT"))
            else:
                pass
        else:
            new_seq.append(base)
    return "".join(new_seq)


def gen_dna(k): return "".join(random.choices("ACGT", k=k))


# (Generating fresh data to ensure variables exist for the loop below)
n_items = 3_000
pool_bc = [gen_dna(12) for _ in range(n_items)]
pool_ins = [gen_dna(random.randint(300, 500)) for _ in range(n_items)]
n_repeat_bc = 500
pool_bc += pool_bc[0:n_repeat_bc]
pool_ins += [gen_dna(random.randint(300, 500)) for _ in range(n_repeat_bc)]
pool_bc += pool_bc[0:n_repeat_bc]
pool_ins += [gen_dna(random.randint(300, 500)) for _ in range(n_repeat_bc)]

# Add very similar sequence that will defeat clustering!
pool_bc += [mutate_sequence(pool_bc[i], 0.03) for i in range(n_repeat_bc)]
pool_ins += [mutate_sequence(pool_ins[i], 0.02) for i in range(n_repeat_bc)]

pool_bc += [mutate_sequence(pool_bc[i], 0.03) for i in range(n_repeat_bc)]
pool_ins += [mutate_sequence(pool_ins[i], 0.02) for i in range(n_repeat_bc)]

pool_bc += [mutate_sequence(pool_bc[i], 0.03) for i in range(n_repeat_bc)]
pool_ins += [mutate_sequence(pool_ins[i], 0.02) for i in range(n_repeat_bc)]


data = []
for i in range(len(pool_bc)):
    n_reads = random.randint(15, 40)
    for _ in range(n_reads):
        data.append({
            "ID": i,
            "Barcode": mutate_sequence(pool_bc[i], 0.01),
            "Insert": mutate_sequence(pool_ins[i], 0.01)
        })

df = pd.DataFrame(data)

# %%
import pandas as pd
import random
from rapidfuzz import process, fuzz
import time
import numpy as np
from scipy.stats import mode
from sklearn.metrics import pairwise_distances
import spoa
from numba import njit, prange
from sklearn.cluster import AgglomerativeClustering
from scipy.cluster.hierarchy import dendrogram


def gen_dna(k): return "".join(random.choices("ACGT", k=k))


class GlobalTimer:
    def __init__(self):
        self.timings = {}
        self.starts = {}

    def start(self, name):
        if name not in self.starts:  # Don't overwrite if nested recursion causes restart
            self.starts[name] = time.perf_counter()

    def stop(self, name):
        if name in self.starts:
            elapsed = time.perf_counter() - self.starts[name]
            self.timings[name] = self.timings.get(name, 0) + elapsed
            del self.starts[name]

    def report(self):
        print("\n" + "=" * 40)
        print(f"{'OPERATION':<30} | {'TIME (s)':<10}")
        print("-" * 43)
        for name, val in sorted(self.timings.items(), key=lambda x: x[1], reverse=True):
            print(f"{name:<30} | {val:.4f}")
        print("=" * 40 + "\n")


timer = GlobalTimer()





@njit(parallel=True, fastmath=True)
def run_bitwise_sims_robust(seed_int, n_sims, n_members, error_rate, valid_muts, lut,
                            top_pct, bot_pct,
                            physical_indices_map, exclusion_dist): # <--- New Args
    scores = np.zeros(n_sims, dtype=np.float32)
    L = len(seed_int)
    n_chunks = (n_members + 63) // 64

    for s in prange(n_sims):
        msa = np.empty((n_members, L), dtype=np.int8)

        # We need a buffer to store the PHYSICAL indices of the variants we find in this sim
        sim_phys_inds = np.empty(L, dtype=np.int32)

        bitmaps = np.zeros((4, L, n_chunks), dtype=np.uint64)

        # 1. Reset & Mutate
        for r in range(n_members):
            msa[r, :] = seed_int

        for r in range(n_members):
            for c in range(L):
                if np.random.random() < error_rate:
                    ri = np.random.randint(0, 4)
                    msa[r, c] = valid_muts[ri]

        # 2. Identify Variants & Pack
        n_var = 0
        for c in range(L):
            v0 = msa[0, c]
            is_var = False
            for r in range(1, n_members):
                if msa[r, c] != v0:
                    is_var = True
                    break

            if is_var:
                # MAP: 'c' is the index in the reduced seed.
                # physical_indices_map[c] is the actual MSA column index.
                sim_phys_inds[n_var] = physical_indices_map[c]

                for r in range(n_members):
                    char = msa[r, c]
                    if char > 3: continue
                    chunk = r // 64
                    bit = r % 64
                    bitmaps[char, n_var, chunk] |= (np.uint64(1) << np.uint64(bit))
                n_var += 1

        # 3. Score with Exclusion Distance
        if n_var < 2:
            scores[s] = 0.0
        else:
            scores[s] = _score_bitwise_internal(bitmaps, n_chunks, L, n_var, lut,
                                                top_pct, bot_pct,
                                                sim_phys_inds, exclusion_dist) # Pass Mapping

    return scores


def remove_invariant_columns(msa_int):
    """
    Identifies and removes columns where values do not change (invariant).
    Returns the reduced matrix and the indices of the kept columns.
    """
    if msa_int.size == 0:
        return msa_int, np.array([])

    mins = msa_int.min(axis=0)
    maxs = msa_int.max(axis=0)

    # If min == max, the column has only one unique value (invariant)
    is_variable = (mins != maxs)
    kept_indices = np.where(is_variable)[0]

    msa_reduced = msa_int[:, kept_indices]
    return msa_reduced, kept_indices



def encode_msa(msa_strings, alphabet="ACGTN-"):
    timer.start("encode_msa")
    """
    Vectorized encoding using ASCII byte views.
    Assumes inputs are ASCII (standard for DNA).
    """
    N = len(msa_strings)
    if N == 0:
        timer.stop("encode_msa")
        return np.array([]), len(alphabet)

    max_len = max(len(s) for s in msa_strings)

    # 1. Pad and convert to single byte-string buffer
    padded_block = "".join([s.ljust(max_len, '-') for s in msa_strings]).encode('ascii')

    # 2. View as NumPy int8 array directly
    arr_view = np.frombuffer(padded_block, dtype=np.int8).copy()
    arr_view = arr_view.reshape(N, max_len)

    # 3. Fast Translation Table
    lookup = np.zeros(256, dtype=np.int8) + (len(alphabet) - 1)
    for idx, char in enumerate(alphabet):
        lookup[ord(char)] = idx

    # 4. Apply translation
    msa_int = lookup[arr_view]

    timer.stop("encode_msa")
    return msa_int, len(alphabet)


def get_marginals(msa_int, vocab_size):
    # Create on hot matrix
    # Use float32 for faster matrix multiplication later
    one_hot = np.eye(vocab_size, dtype=np.float32)[msa_int]
    # Calculate frequencies of each base/N/- at each position in MSA
    P_i = one_hot.mean(axis=0)
    return one_hot, P_i



def get_elbow_columns(mi_matrix, exclusion_distance=5, verbose=0):
    timer.start("get_elbow_columns")
    L = mi_matrix.shape[0]
    # Note: When using reduced matrix, exclusion_distance refers to indices in the reduced set
    mask = np.triu(np.ones((L, L), dtype=bool), k=exclusion_distance + 1)
    rows, cols = np.where(mask)
    scores = mi_matrix[rows, cols]

    if len(scores) == 0:
        timer.stop("get_elbow_columns")
        return np.array([])
    # 1. Sort Descending
    sorted_indices = np.argsort(scores)[::-1]
    sorted_scores = scores[sorted_indices]

    # 2. Determine "Signal End" (Noise Floor Truncation)
    noise_floor = np.percentile(scores, 25)
    valid_mask = sorted_scores > noise_floor
    n_signal_points = np.sum(valid_mask)
    min_points = min(len(sorted_scores), 5)
    cutoff_idx = max(n_signal_points, min_points)

    # 3. Truncate for Geometry Calculation
    curve_y = sorted_scores[:cutoff_idx]
    n_points = len(curve_y)

    if n_points < 3:
        timer.stop("get_elbow_columns")
        return np.unique(np.concatenate([rows[sorted_indices[:n_points]], cols[sorted_indices[:n_points]]]))
    # 4. Standard Kneedle on Truncated Curve
    x_norm = np.linspace(0, 1, n_points)
    y_norm = (curve_y - curve_y.min()) / (curve_y.max() - curve_y.min() + 1e-9)

    line_vec = np.array([1.0, -1.0])
    line_vec = line_vec / np.linalg.norm(line_vec)
    vec_from_start = np.stack([x_norm, y_norm - 1.0], axis=1)
    distances = np.abs(vec_from_start[:, 0] * line_vec[1] - vec_from_start[:, 1] * line_vec[0])

    # 5. Select
    elbow_idx = np.argmax(distances)
    if elbow_idx == 0:
        for i in range(1, n_points - 1):
            if curve_y[i] >= (curve_y[0] * 0.95):
                elbow_idx = i
            else:
                break
    n_selected = elbow_idx + 1
    selected_indices = sorted_indices[:n_selected]
    selected_columns = np.unique(np.concatenate([rows[selected_indices], cols[selected_indices]]))

    timer.stop("get_elbow_columns")
    return selected_columns


def plot_dendrogram(model, **kwargs):
    counts = np.zeros(model.children_.shape[0])
    n_samples = len(model.labels_)
    for i, merge in enumerate(model.children_):
        current_count = 0
        for child_idx in merge:
            if child_idx < n_samples:
                current_count += 1
            else:
                current_count += counts[child_idx - n_samples]
        counts[i] = current_count
    linkage_matrix = np.column_stack([model.children_, model.distances_, counts]).astype(float)
    dendrogram(linkage_matrix, **kwargs)


def fast_consensus(msa_list, min_threshold=0.5, high_conf_threshold=0.85):
    """
    Vectorized consensus with strict ambiguity detection.

    Rules:
      1. TIE (e.g., 2 A's, 2 G's) -> 'N'
      2. Support < min_threshold  -> 'N'
      3. Support < high_conf      -> Lower Case (e.g., 'a')
      4. Support >= high_conf     -> Upper Case (e.g., 'A')
    """
    if not msa_list:
        return ""

    # 1. Setup Vectorized Arrays
    arr = np.array([list(s) for s in msa_list], dtype='S1')
    arr_int = arr.view(np.uint8)
    n_seqs, length = arr_int.shape

    GAP = 45  # '-'
    N_VAL = 78  # 'N'
    TO_LOWER = 32  # ASCII offset for A->a

    # 2. Count Frequencies (Vectorized)
    unique_chars = np.unique(arr_int)
    # Shape: (num_unique, length)
    counts = (arr_int == unique_chars[:, None, None]).sum(axis=1)

    # 3. Determine Winners & Detect Ties
    max_counts = counts.max(axis=0)
    max_indices = counts.argmax(axis=0)

    # Check for ties: Count how many rows in 'counts' equal the 'max_count'
    # If sum > 1, it means two or more bases are tied for the winner.
    tie_counts = (counts == max_counts).sum(axis=0)
    is_tie = tie_counts > 1

    # Map to Consensus Candidates
    consensus_arr = unique_chars[max_indices]
    freqs = max_counts / n_seqs

    # 4. Apply Rules
    is_gap = (consensus_arr == GAP)

    # Rule A: Ties or Low Support -> 'N'
    # Note: We enforce N if it's a tie, OR if freq is below min threshold.
    ambiguous_mask = (is_tie) | (freqs < min_threshold)

    # Only overwrite non-gaps (preserving gaps allows us to strip them later)
    # If a gap is the clear winner, we leave it as gap.
    # If a gap is TIED with a base (e.g. 2 gaps, 2 As), is_tie=True, so it becomes N.
    consensus_arr[ambiguous_mask & (~is_gap)] = N_VAL

    # Rule B: Mid Confidence -> Lower Case
    # Valid only if NOT ambiguous, NOT a gap, and freq < high_threshold
    mid_conf_mask = (~ambiguous_mask) & (freqs < high_conf_threshold) & (~is_gap)

    # Safety: Only lowercase actual letters (A-Z)
    is_upper_alpha = (consensus_arr >= 65) & (consensus_arr <= 90)
    consensus_arr[mid_conf_mask & is_upper_alpha] += TO_LOWER

    # 5. Output
    # Remove gaps
    final_int_seq = consensus_arr[consensus_arr != GAP]
    return final_int_seq.tobytes().decode('utf-8')


def get_poa_consensus(barcode_series, bias_towards=None):
    timer.start("SPOA_Consensus_Total")
    barcode_list = barcode_series.tolist()
    if bias_towards is not None:
        barcode_list.append(bias_towards)

    _, msa = spoa.poa(barcode_list, algorithm=1)
    consensus = fast_consensus(msa)
    timer.stop("SPOA_Consensus_Total")
    return consensus



@njit(parallel=True, fastmath=True)
def compute_mi_from_joint_optimized(joint_probs_flat, P_i_flat, L, A):
    """
    Optimized version with better memory access patterns.
    """
    mi = np.zeros((L, L), dtype=np.float32)
    epsilon = 1e-12
    # Precompute log(P_i) to avoid redundant calculations
    log_P_i = np.zeros(L * A, dtype=np.float32)
    for idx in range(L * A):
        if P_i_flat[idx] > epsilon:
            log_P_i[idx] = np.log(P_i_flat[idx])
    for i in prange(L):
        for j in range(i + 1, L):
            mi_val = 0.0

            for a in range(A):
                p_x = P_i_flat[i * A + a]
                if p_x <= epsilon:
                    continue

                log_p_x = log_P_i[i * A + a]

                for b in range(A):
                    p_y = P_i_flat[j * A + b]
                    if p_y <= epsilon:
                        continue

                    row_idx = i * A + a
                    col_idx = j * A + b
                    p_xy = joint_probs_flat[row_idx, col_idx]

                    if p_xy > epsilon:
                        log_p_y = log_P_i[j * A + b]
                        mi_val += p_xy * (np.log(p_xy) - log_p_x - log_p_y)

            mi[i, j] = mi_val
            mi[j, i] = mi_val

    return mi


def compute_mi_scores_optimized_v2(one_hot, P_i, timer):
    """
    Enhanced version with precomputed logs.
    """
    timer.start("compute_mi_hybrid_execution")

    N, L, A = one_hot.shape

    # BLAS multiplication (unchanged - already optimal)
    flat_view = one_hot.reshape(N, L * A)
    joint_counts = np.dot(flat_view.T, flat_view)
    joint_probs_flat = joint_counts / N

    # Use optimized Numba function
    result = compute_mi_from_joint_optimized(joint_probs_flat, P_i.flatten(), L, A)

    timer.stop("compute_mi_hybrid_execution")
    return result



def fast_spoa(sequences, algorithm=1, mode='msa', max_initial_reads=50):
    """
    Corrected wrapper for the functional spoa.poa() binding.
    """
    # Ensure input is a standard list of strings
    if not isinstance(sequences, list):
        sequences = list(sequences)

    if not sequences:
        return "", []

    # --- PATH 1: Consensus Only (Fast / Approximate) ---
    # Use this for 'SPOA_alignment_initial' to break the 10s bottleneck.
    # We subsample to keep it fast.
    if mode == 'consensus' and len(sequences) > max_initial_reads:
        subset = random.sample(sequences, max_initial_reads)
        try:
            # Run SPOA on just the small subset
            consensus, _ = spoa.poa(subset, algorithm=algorithm)
            return consensus, []  # Return empty MSA because subset MSA won't match full input
        except Exception as e:
            print(f"SPOA Subset Error: {e}")
            return "", []

    # --- PATH 2: Full MSA (Required for MI Check) ---
    # Use this for 'check_cluster_integrity'. We CANNOT subsample here
    # because we need the MSA to match the input rows 1-to-1.
    try:
        # The library calculates everything in one go
        consensus, msa = spoa.poa(sequences, algorithm=algorithm)
        return consensus, msa
    except Exception as e:
        print(f"SPOA Full Error: {e}")
        return "", []

@njit
def create_mi_lookup(n_members):
    lut = np.zeros((n_members + 1, n_members + 1, n_members + 1), dtype=np.float32)
    N = float(n_members)
    epsilon = 1e-12

    for c_xy in range(1, n_members + 1):
        for c_x in range(1, n_members + 1):
            for c_y in range(1, n_members + 1):
                # Valid counts only
                if c_xy <= c_x and c_xy <= c_y:
                    p_xy = c_xy / N
                    p_x = c_x / N
                    p_y = c_y / N

                    term = p_xy * np.log(p_xy / (p_x * p_y))
                    lut[c_xy, c_x, c_y] = term
    return lut


@njit(inline='always')
def popcount64(x):
    """
    SWAR algorithm for 64-bit population count.
    Inline always to ensure it compiles to optimal assembly.
    """
    x = np.uint64(x)
    m1 = np.uint64(0x5555555555555555)
    m2 = np.uint64(0x3333333333333333)
    m4 = np.uint64(0x0f0f0f0f0f0f0f0f)

    x -= (x >> np.uint64(1)) & m1
    x = (x & m2) + ((x >> np.uint64(2)) & m2)
    x = (x + (x >> np.uint64(4))) & m4
    x = (x * np.uint64(0x0101010101010101)) >> np.uint64(56)
    return int(x)


@njit(fastmath=True)
def _score_bitwise_internal(bitmaps, n_chunks, L, n_var, lut, top_pct, bottom_pct,
                            variant_indices, exclusion_dist): # <--- New Args
    """
    Computes MI with physical distance masking.
    variant_indices: Array of actual MSA column indices for the variants.
    exclusion_dist: Minimum distance required to calculate MI.
    """
    # 1. Marginals (Unchanged)
    marginals = np.zeros((n_var, 4), dtype=np.int32)
    for i in range(n_var):
        for b in range(4):
            count = 0
            for k in range(n_chunks):
                val = bitmaps[b, i, k]
                if val > 0: count += popcount64(val)
            marginals[i, b] = count

    # 2. Pairwise MI
    row_mis = np.zeros(n_var, dtype=np.float32)
    max_ratio = 0.0
    damping = 0.01

    k_top = max(1, int(L * top_pct))
    k_bottom = max(1, int(L * bottom_pct))
    n_zeros_implicit = L - n_var

    for i in range(n_var):
        phys_i = variant_indices[i] # Get physical index

        for j in range(n_var):
            phys_j = variant_indices[j] # Get physical index

            # --- [NEW] BAND MASKING ---
            # Mask diagonal AND neighbors within exclusion_dist
            dist = phys_i - phys_j
            if dist < 0: dist = -dist # abs()

            if dist <= exclusion_dist:
                row_mis[j] = 0.0
                continue
            # --------------------------

            mi_val = 0.0

            # 4x4 Base Loop
            for b1 in range(4):
                c_x = marginals[i, b1]
                if c_x == 0: continue
                for b2 in range(4):
                    c_y = marginals[j, b2]
                    if c_y == 0: continue

                    c_xy = 0
                    for k in range(n_chunks):
                        bits = bitmaps[b1, i, k] & bitmaps[b2, j, k]
                        if bits > 0: c_xy += popcount64(bits)

                    if c_xy > 0: mi_val += lut[c_xy, c_x, c_y]

            row_mis[j] = mi_val

        # 3. Ratio Logic (Unchanged)
        row_mis = np.sort(row_mis)

        take_top = min(k_top, n_var)
        sum_top = 0.0
        if take_top > 0:
            for k in range(take_top):
                sum_top += row_mis[n_var - 1 - k]
        top_mean = sum_top / k_top

        sum_bot = 0.0
        if k_bottom > n_zeros_implicit:
            needed = k_bottom - n_zeros_implicit
            take_bot = min(needed, n_var)
            for k in range(take_bot):
                sum_bot += row_mis[k]
            bottom_mean = sum_bot / k_bottom
        else:
            bottom_mean = 0.0

        ratio = (top_mean + damping) / (bottom_mean + damping)
        if ratio > max_ratio:
            max_ratio = ratio

    return max_ratio



def check_cluster_integrity_mi_hyper_optimized(cluster_df, expected_error_rate, timer,
                                               top_pct=0.004, bottom_pct=0.75,
                                               verbose=0, PLOTS=False,
                                               mi_exclusion_distance=3,
                                               mi_percentile=99):
    timer.start("MI_Integrity_Check_Total")

    barcodes = cluster_df['Barcode'].tolist()
    inserts = cluster_df['Insert'].tolist()
    n_members = len(barcodes)

    if n_members <= 5:
        timer.stop("MI_Integrity_Check_Total")
        return False

    # 1. Alignment & Encoding
    timer.start("SPOA_alignment")
    _, msa_barcodes = spoa.poa(barcodes, algorithm=1)
    _, msa_inserts = fast_spoa(inserts, algorithm=1)
    timer.stop("SPOA_alignment")

    msa_strings = [b + "-" * 1 + i for b, i in zip(msa_barcodes, msa_inserts)]
    msa_int, vocab_size = encode_msa(msa_strings)

    alphabet = "ACGTN-"
    char_to_int = {c: i for i, c in enumerate(alphabet)}
    valid_muts = np.array([char_to_int[c] for c in "ACGT"], dtype=np.int8)

    # 2. LUT
    lut = create_mi_lookup(n_members)

    # 3. Real Score
    timer.start("Real_Score")
    msa_reduced, kept_indices = remove_invariant_columns(msa_int)
    n_var_real = len(kept_indices)
    L_real = msa_int.shape[1]
    kept_indices_32 = kept_indices.astype(np.int32)

    if n_var_real < 2:
        real_score = 0.0
    else:
        n_chunks = (n_members + 63) // 64
        bitmaps = np.zeros((4, n_var_real, n_chunks), dtype=np.uint64)
        msa_contig = np.ascontiguousarray(msa_reduced)

        for i in range(n_var_real):
            for r in range(n_members):
                char = msa_contig[r, i]
                if char > 3: continue
                chunk = r // 64
                bit = r % 64
                bitmaps[char, i, chunk] |= (np.uint64(1) << np.uint64(bit))

        real_score = _score_bitwise_internal(bitmaps, n_chunks, L_real, n_var_real, lut,
                                             top_pct, bottom_pct,
                                             kept_indices_32, mi_exclusion_distance)
    timer.stop("Real_Score")

    if real_score == 0.0:
        timer.stop("MI_Integrity_Check_Total")
        return False

    # 4. Simulations with CORRECTED Early Stopping
    timer.start("Sim_Parallel")
    seed_idx = np.random.randint(n_members)
    seed_int = np.ascontiguousarray(msa_int[seed_idx])

    all_sim_scores = []

    N_BATCH = 20
    N_MAX_SIMS = 100

    # Assume outlier is True until we prove it's safe (or run out of sims)
    # However, for the loop logic, we track the state per iteration.
    is_outlier = False

    for n_current_sims in range(N_BATCH, N_MAX_SIMS + 1, N_BATCH):

        # Run batch
        batch_scores = run_bitwise_sims_robust(
            seed_int,
            N_BATCH,
            n_members,
            expected_error_rate,
            valid_muts,
            lut,
            top_pct,
            bottom_pct,
            kept_indices_32,
            mi_exclusion_distance
        )
        all_sim_scores.extend(batch_scores)
        current_total = len(all_sim_scores)

        sim_arr = np.array(all_sim_scores)
        threshold = np.percentile(sim_arr, mi_percentile)

        if real_score < threshold:
            # === EARLY STOP (CLEAN) ===
            # The real score is buried in the noise.
            # It is SAFE to stop. We don't need 100 sims to know it's not an outlier.
            is_outlier = False
            if verbose >= 2:
                print \
                    (f"  > Sim Stop (Clean): Real={real_score:.4f} < P{mi_percentile}={threshold:.4f} after {current_total} sims.")
            break
        else:
            # === CONTINUE (SUSPICIOUS) ===
            # The real score is higher than current noise.
            # We MUST continue to verify this isn't just a fluke of small sample size.
            is_outlier = True
            if verbose >= 2 and current_total < N_MAX_SIMS:
                print(f"  > Suspicious (Real > Threshold). Extending sims... {current_total}/{N_MAX_SIMS}")

    timer.stop("Sim_Parallel")

    # Final Reporting
    if is_outlier:
        if verbose >= 1:
            print(f"!!! Outlier: Real={real_score:.4f} > P{mi_percentile}={threshold:.4f} (Sims: {current_total})")
    # No else needed for verbose, the loop printed the 'Clean' message

    timer.stop("MI_Integrity_Check_Total")
    return is_outlier





def calculate_msa_mi_and_top_cols(barcodes, inserts, verbose=0, mi_exclusion_distance=5):
    timer.start("SPOA_alignment_initial")
    # FIX: Use algorithm=1 (Global) to match the integrity check logic.
    _, msa_barcodes = fast_spoa(barcodes, algorithm=1, mode='msa')
    _, msa_inserts = fast_spoa(inserts, algorithm=1, mode='msa')
    timer.stop("SPOA_alignment_initial")

    msa_strings = [b + "-" * 1 + i for b, i in zip(msa_barcodes, msa_inserts)]
    len_msa_inserts = len(msa_inserts[0])
    msa_int, vocab_size = encode_msa(msa_strings)

    timer.start("Filter_Invariant")
    msa_reduced, kept_indices = remove_invariant_columns(msa_int)
    timer.stop("Filter_Invariant")

    if msa_reduced.shape[1] < 2:
        return msa_int, np.zeros((0, 0)), np.array([]), len_msa_inserts, kept_indices

    one_hot, P_i = get_marginals(msa_reduced, vocab_size)
    mi_matrix_reduced = compute_mi_scores_optimized_v2(one_hot, P_i, timer)

    # ==============================================================================
    # [NEW] MASK LOCAL NEIGHBORS (Band Masking)
    # ==============================================================================
    # We must mask interactions between columns that are physically close in the MSA
    # to prevent local sequencing errors (indels/homopolymers) from dominating MI.

    # 1. Compute physical distance matrix using broadcasting on kept_indices
    #    kept_indices is shape (N_cols,), this creates (N_cols, N_cols)
    physical_dist_matrix = np.abs(kept_indices[:, None] - kept_indices[None, :])

    # 2. Create boolean mask: True where distance is smaller than threshold
    #    This automatically covers the diagonal (dist=0)
    local_noise_mask = physical_dist_matrix < mi_exclusion_distance

    # 3. Apply mask: Set MI to 0.0 for neighbors
    mi_matrix_reduced[local_noise_mask] = 0.0
    # ==============================================================================

    # Note: We still pass mi_exclusion_distance to get_elbow_columns if it needs it
    # for other logic, but the matrix is now clean.
    top_cols_reduced = get_elbow_columns(mi_matrix_reduced, mi_exclusion_distance, verbose=verbose)

    top_cols_original = kept_indices[top_cols_reduced] if len(top_cols_reduced) > 0 else np.array([])
    return msa_int, mi_matrix_reduced, top_cols_original, len_msa_inserts, kept_indices


def cluster_msa_subset(msa_subset, expected_error_rate, error_rate_multiplier=None, jump_thresh=None):
    timer.start("hamming_distance_matrix")
    dist_matrix_subset = pairwise_distances(msa_subset, metric='hamming')
    timer.stop("hamming_distance_matrix")

    if dist_matrix_subset.shape[0] == 1:
        return dist_matrix_subset, np.array([0])

    if error_rate_multiplier is not None:
        d_thresh = expected_error_rate * error_rate_multiplier
    else:
        temp = dist_matrix_subset.copy()
        np.fill_diagonal(temp, np.inf)
        d_thresh = np.min(temp) * jump_thresh + expected_error_rate

    timer.start("agglomerative_clustering")
    agg = AgglomerativeClustering(metric="precomputed", linkage="single", distance_threshold=d_thresh, n_clusters=None)
    labels = agg.fit_predict(dist_matrix_subset)
    timer.stop("agglomerative_clustering")
    return dist_matrix_subset, labels


def cluster_barcode_insert_pairs(barcodes, inserts, mi_exclusion_distance, expected_error_rate,
                                 error_rate_multiplier=None, jump_thresh=None, verbose=0, subset_msa=True):
    msa_int, mi_matrix, top_cols, len_msa_inserts, _ = calculate_msa_mi_and_top_cols(barcodes, inserts, verbose,
                                                                                     mi_exclusion_distance)
    msa_subset = msa_int[:, top_cols] if (subset_msa and len(top_cols) > 0) else msa_int
    dist_matrix_subset, labels = cluster_msa_subset(msa_subset, expected_error_rate, error_rate_multiplier, jump_thresh)
    return msa_int, mi_matrix, msa_subset, dist_matrix_subset, labels, len_msa_inserts


def recursive_outlier_removal(all_df, cluster_df, filtered_dist_matrix, expected_error_rate, percentile_th,
                              verbose, error_rate_multiplier=1.2, n_decoys=50):
    if len(cluster_df) < 2: return cluster_df
    m = filtered_dist_matrix.astype(float);
    m[np.triu_indices_from(m)] = np.nan
    if np.nanmax(m) <= expected_error_rate * error_rate_multiplier: return cluster_df

    agg = AgglomerativeClustering(metric="precomputed", linkage="single", distance_threshold=np.nanmedian(m),
                                  n_clusters=None)
    labels = agg.fit_predict(filtered_dist_matrix)

    largest_idx = np.where(labels == np.bincount(labels).argmax())[0]
    largest_sub_dist = filtered_dist_matrix[np.ix_(largest_idx, largest_idx)]
    best_core = cluster_df['Insert'].iloc[largest_idx[np.argmin(np.mean(largest_sub_dist, axis=1))]]

    timer.start("Fuzzy_CDIST_Calculations")
    all_ratios = process.cdist([best_core], list(cluster_df['Insert']), scorer=fuzz.ratio, dtype=np.float32)[0]
    timer.stop("Fuzzy_CDIST_Calculations")

    outlier_pos = np.argmin(all_ratios)

    # Decoy Check
    timer.start("Fuzzy_CDIST_Calculations")
    decoy_ratios = \
        process.cdist([cluster_df['Insert'].iloc[outlier_pos]], all_df['Insert'].sample(n=n_decoys), scorer=fuzz.ratio,
                      dtype=np.float32)[0]
    timer.stop("Fuzzy_CDIST_Calculations")

    if all_ratios[outlier_pos] >= np.percentile(decoy_ratios, percentile_th):
        return cluster_df

    keep_mask = np.arange(len(filtered_dist_matrix)) != outlier_pos
    return recursive_outlier_removal(all_df, cluster_df.iloc[keep_mask],
                                     filtered_dist_matrix[np.ix_(keep_mask, keep_mask)],
                                     expected_error_rate, percentile_th, verbose, error_rate_multiplier, n_decoys)


def recursive_mi_splitting(cluster_df, all_df, expected_error_rate, timer, verbose, mi_percentile, depth=0, max_depth=3):
    """
    Recursively splits a cluster if MI check indicates it is a mix of sequences.
    Splitting is based on clustering the 'top columns' (highest MI interactions).
    """
    # 1. Fast Integrity Check
    is_suspicious = check_cluster_integrity_mi_hyper_optimized(cluster_df, expected_error_rate, timer, verbose=verbose,
                                                               mi_percentile=mi_percentile)

    # Base cases: Clean cluster, max depth, or too small to split
    if not is_suspicious:
        cluster_df = cluster_df.copy()
        cluster_df['mi_warning'] = False
        return [cluster_df]

    if depth >= max_depth:
        if verbose >= 1: print(f"  > Max depth reached ({depth}). Returning suspicious cluster.")
        cluster_df = cluster_df.copy()
        cluster_df['mi_warning'] = True
        return [cluster_df]

    if len(cluster_df) < 6:
        if verbose >= 1: print(f"  > Cluster too small to split ({len(cluster_df)}). Returning.")
        cluster_df = cluster_df.copy()
        cluster_df['mi_warning'] = True
        return [cluster_df]

    if verbose >= 1:
        print(f"  > Splitting cluster (Depth {depth}) - Size {len(cluster_df)}")

    # 2. Identify Important Columns for Splitting
    barcodes = cluster_df['Barcode'].tolist()
    inserts = cluster_df['Insert'].tolist()

    try:
        # Use existing function to get top columns
        msa_int, mi_matrix, top_cols, _, kept_indices = calculate_msa_mi_and_top_cols(barcodes, inserts, verbose=0,
                                                                                      mi_exclusion_distance=3)
    except Exception as e:
        print(f"Error in MI split calc: {e}")
        cluster_df = cluster_df.copy()
        cluster_df['mi_warning'] = True
        return [cluster_df]

    if verbose >= 2:
        print(f"    > Initial Top Cols found: {len(top_cols)}")

    # 3. Split based on Top Columns
    if len(top_cols) < 1:
        # Fallback 1: Try top 3 MI columns
        if mi_matrix is not None and mi_matrix.size > 0:
            if verbose >= 1: print("    > Elbow failed, forcing fallback split on Top 3 MI columns.")
            mi_sums = mi_matrix.sum(axis=1)
            fallback_indices = np.argsort(mi_sums)[-3:]
            top_cols = kept_indices[fallback_indices]

        # Fallback 2: If still no top cols, use ALL variant columns.
        # If MI is high, the signal MUST be in the variants somewhere.
        if len(top_cols) < 1 and len(kept_indices) > 0:
            if verbose >= 1: print("    > Fallback failed. Using ALL variant columns for split.")
            top_cols = kept_indices

        # If still nothing (no variants at all?), abort.
        if len(top_cols) < 1:
            if verbose >= 1: print("    > No variant columns found (identical sequences?). Aborting split.")
            cluster_df = cluster_df.copy()
            cluster_df['mi_warning'] = True
            return [cluster_df]

    # Extract only the high-MI columns
    msa_subset = msa_int[:, top_cols]

    # === FIX: ROBUST VECTORIZED ONE-HOT ENCODING ===
    # Use int32 to prevent any overflow issues and vectorize for speed.
    N_sub, C_sub = msa_subset.shape
    vocab_size = 6  # ACGTN-

    # Flatten for advanced indexing
    flat_vals = msa_subset.flatten()

    # Generate grid indices
    rows = np.repeat(np.arange(N_sub), C_sub)
    cols = np.tile(np.arange(C_sub), N_sub)

    # Mask invalid values to be safe
    mask = (flat_vals >= 0) & (flat_vals < vocab_size)

    valid_rows = rows[mask]
    # Calculate flattened column index for One-Hot matrix
    valid_cols = cols[mask] * vocab_size + flat_vals[mask]

    # Initialize with int32 (safe)
    one_hot = np.zeros((N_sub, C_sub * vocab_size), dtype=np.int32)
    one_hot[valid_rows, valid_cols] = 1

    timer.start("ward_splitting")
    # Ward linkage ensures we find the structural split, not just peel off an outlier
    agg = AgglomerativeClustering(n_clusters=2, linkage='ward')
    labels = agg.fit_predict(one_hot)
    timer.stop("ward_splitting")

    df_0 = cluster_df.iloc[labels == 0]
    df_1 = cluster_df.iloc[labels == 1]

    # Sanity check: Ensure neither side is strictly empty.
    # We accept 1 vs Rest splits now.
    if len(df_0) < 1 or len(df_1) < 1:
        if verbose >= 1: print(f"    > Split failed (Empty result: {len(df_0)} vs {len(df_1)}). Aborting.")
        cluster_df = cluster_df.copy()
        cluster_df['mi_warning'] = True
        return [cluster_df]

    if verbose >= 1:
        print(f"    > Split successful: {len(df_0)} vs {len(df_1)}")

    # 4. Recurse on children
    results_0 = recursive_mi_splitting(df_0, all_df, expected_error_rate, timer, verbose, mi_percentile, depth + 1, max_depth)
    results_1 = recursive_mi_splitting(df_1, all_df, expected_error_rate, timer, verbose, mi_percentile, depth + 1, max_depth)

    return results_0 + results_1


def full_analysis(sub_df, all_df, barcode_target, percentile_th, expected_error_rate,
                  verbose, mi_exclusion_distance, mi_percentile, cluster_again_total_mean_thresh=2,
                  cluster_again_single_mean_thresh=3):
    if len(sub_df) < 2:
        if 'cluster' not in sub_df.columns: sub_df = sub_df.copy(); sub_df['cluster'] = -1
        return sub_df

    # Initial Clustering
    barcodes = sub_df['Barcode'].tolist()
    inserts = sub_df['Insert'].tolist()

    _, _, _, dist_matrix_subset, labels, _ = cluster_barcode_insert_pairs(
        barcodes, inserts, mi_exclusion_distance, expected_error_rate,
        error_rate_multiplier=3, verbose=0, subset_msa=False
    )

    # Unique cluster IDs to prevent collision in later steps
    labels = labels + hash(frozenset(sub_df.index)) % 10_000_000
    sub_df['cluster'] = labels

    final_clusters = []
    unique_labels = list(set(labels))

    for label in unique_labels:
        this_cluster = sub_df[sub_df['cluster'] == label]

        # 1. Outlier Removal (Existing logic)
        indices = np.where(labels == label)[0]
        filtered_dist_matrix = dist_matrix_subset[np.ix_(indices, indices)]
        processed_cluster = recursive_outlier_removal(
            all_df, this_cluster, filtered_dist_matrix,
            expected_error_rate, percentile_th, verbose
        )

        # 2. Recursive MI Check & Splitting (New Logic)
        if len(processed_cluster) >= 8 and label != -1:
            # This function returns a LIST of dataframes (1 if clean, >1 if split)
            split_results = recursive_mi_splitting(
                processed_cluster, all_df, expected_error_rate, timer, verbose, mi_percentile
            )

            # Assign new sub-cluster IDs if split occurred
            for i, res_df in enumerate(split_results):
                if len(split_results) > 1:
                    # Append suffix to label to track lineage (e.g., 101_0, 101_1)
                    res_df = res_df.copy()
                    res_df['cluster'] = label * 100 + i  # Simple offset for sub-clusters
                final_clusters.append(res_df)

        else:
            processed_cluster = processed_cluster.copy()
            processed_cluster['mi_warning'] = False
            final_clusters.append(processed_cluster)

    if not final_clusters:
        return pd.DataFrame(columns=sub_df.columns)

    result = pd.concat(final_clusters)
    if verbose >= 2:
        timer.report()
    return result


def filter_result_df(result, barcode_target, verbose,
                     filter_target=False,
                     min_barcode_ratio_hq=0.975):
    result = result.copy()
    unique_clusters = result['cluster'].unique()
    consensus_map = {}

    try:
        timer.start("filter_consensus_generation")
    except:
        pass

    for cl in unique_clusters:
        subset = result.loc[result['cluster'] == cl, 'Barcode']
        consensus_map[cl] = get_poa_consensus(subset)

    try:
        timer.stop("filter_consensus_generation")
    except:
        pass

    result['cluster_consensus_bc'] = result['cluster'].map(consensus_map)

    if filter_target:
        result = result[
            (result['cluster_consensus_bc'].str.upper() == barcode_target.upper()) |
            ((result.groupby('cluster')['Barcode'].transform('size') == 2) &
             (result.groupby('cluster')['Barcode'].transform(lambda x: (x == barcode_target).any()))
             )
            ]

    if result.empty: return result

    def get_mean_consistency(df_chunk):
        consensus = df_chunk['cluster_consensus_bc'].iloc[0]
        if not consensus: return 0.0
        scores = [fuzz.ratio(b, consensus) for b in df_chunk['Barcode']]
        return np.mean(scores) / 100.0

    cluster_scores = result.groupby('cluster').apply(get_mean_consistency, include_groups=False)
    result['cluster_mean_barcode_sim'] = result['cluster'].map(cluster_scores)
    result['barcodes_consistent'] = result['cluster_mean_barcode_sim'] >= min_barcode_ratio_hq

    result['cluster_consensus_insert'] = result.groupby('cluster')['Insert'].transform(get_poa_consensus)

    unique = [u for u in sorted(result['cluster'].unique()) if u != -1]
    mapping = {old: new for new, old in enumerate(unique)}
    result['cluster'] = result['cluster'].map(lambda x: mapping.get(x, -1))

    return result

# %%
# ==== PARAMS =====

verbose = 6
percentile_th = 95
expected_error_rate = 0.01
PLOTS = True
mi_exclusion_distance = 5
n_sims = 150
sim_percentile = 0.1
mi_percentile = 99

# ==== RUN =====

barcode_counts = df['Barcode'].value_counts()
all_barcodes = np.array(barcode_counts.index.tolist())

for i, (top_bc, count) in enumerate(barcode_counts.head(200).items()):

    if verbose >= 1:
        print(f"\n\n=============\n{top_bc}")
        print(f"Processing Top Barcode #{i + 1}: {top_bc} (Count: {count})")

    # top_bc = "TCGATCGCGTGA" # Force specific barcode if needed for debug

    # RapidFuzz
    scores = process.cdist([top_bc], all_barcodes, scorer=fuzz.ratio, dtype=np.float32)[0]
    candidate_bcs = all_barcodes[np.where(scores > 88)[0]]
    filtered_df = df[df['Barcode'].isin(candidate_bcs)].copy()

    if verbose >= 3:
        print(f"length of filtered df: {len(filtered_df)}")

    # filtered_df = pd.read_csv("~/Downloads/fml.csv")

    if filtered_df.empty: continue

    if verbose >= 2:
        print(f"  > RapidFuzz gathered {len(filtered_df)} reads")

    result_df = full_analysis(filtered_df, df, top_bc,
                              percentile_th=percentile_th, verbose=verbose, expected_error_rate=expected_error_rate,
                              mi_exclusion_distance=mi_exclusion_distance, mi_percentile=mi_percentile)

    result_df2 = filter_result_df(result_df, top_bc, verbose, filter_target=True)

    # Create the count DataFrame first (using the recommended groupby method)
    combo_counts_df = result_df2.groupby(
        ['ID', 'cluster', 'mi_warning', 'barcodes_consistent']).size().reset_index(name='count')

    # Now, sort the DataFrame
    combo_counts_df.sort_values(by=['cluster', 'count'], ascending=[True, False], inplace=True)

        # Print the final result
    print(combo_counts_df)

    # print(result_df2)
# Out:
# =============
# TTACACAGACTA
# Processing Top Barcode #1: TTACACAGACTA (Count: 196)
# length of filtered df: 208
#   > RapidFuzz gathered 208 reads
#   > Sim Stop (Clean): Real=13.9740 < P99=19.9715 after 20 sims.
#   > Suspicious (Real > Threshold). Extending sims... 20/100
#   > Suspicious (Real > Threshold). Extending sims... 40/100
#   > Suspicious (Real > Threshold). Extending sims... 60/100
#   > Suspicious (Real > Threshold). Extending sims... 80/100
# !!! Outlier: Real=56.6675 > P99=9.6435 (Sims: 100)
#   > Splitting cluster (Depth 0) - Size 136
#     > Initial Top Cols found: 321
#     > Split successful: 96 vs 40
#   > Suspicious (Real > Threshold). Extending sims... 20/100
#   > Suspicious (Real > Threshold). Extending sims... 40/100
#   > Suspicious (Real > Threshold). Extending sims... 60/100
#   > Suspicious (Real > Threshold). Extending sims... 80/100
# !!! Outlier: Real=57.7748 > P99=12.8216 (Sims: 100)
#   > Splitting cluster (Depth 1) - Size 96
#     > Initial Top Cols found: 249
#     > Split successful: 66 vs 30
#   > Suspicious (Real > Threshold). Extending sims... 20/100
#   > Suspicious (Real > Threshold). Extending sims... 40/100
#   > Suspicious (Real > Threshold). Extending sims... 60/100
#   > Suspicious (Real > Threshold). Extending sims... 80/100
# !!! Outlier: Real=65.6982 > P99=16.5542 (Sims: 100)
#   > Splitting cluster (Depth 2) - Size 66
#     > Initial Top Cols found: 187
#     > Split successful: 29 vs 37
#   > Sim Stop (Clean): Real=15.9995 < P99=25.7397 after 20 sims.
#   > Sim Stop (Clean): Real=13.4251 < P99=25.7683 after 20 sims.
#   > Sim Stop (Clean): Real=15.6145 < P99=29.2012 after 20 sims.
#   > Sim Stop (Clean): Real=12.7397 < P99=23.6716 after 20 sims.
#   > Sim Stop (Clean): Real=13.4449 < P99=13.5818 after 20 sims.
#
# ========================================
# OPERATION                      | TIME (s)
# -------------------------------------------
# MI_Integrity_Check_Total       | 3.1442
# Sim_Parallel                   | 1.8196
# Real_Score                     | 0.7084
# compute_mi_hybrid_execution    | 0.6768
# SPOA_alignment_initial         | 0.6255
# SPOA_alignment                 | 0.5211
# get_elbow_columns              | 0.0260
# ward_splitting                 | 0.0117
# hamming_distance_matrix        | 0.0102
# Fuzzy_CDIST_Calculations       | 0.0085
# encode_msa                     | 0.0061
# agglomerative_clustering       | 0.0018
# Filter_Invariant               | 0.0005
# ========================================
#
#      ID  cluster  mi_warning  barcodes_consistent  count
# 1  3315        0       False                 True     35
# 2  3815        1       False                 True     37
# 4  4815        2       False                 True     29
# 0   315        3       False                 True     37
# 5  5315        4       False                 True     30
# 3  4315        5       False                 True     40
#
#
# =============
# GCCTAAGCCTTG
# Processing Top Barcode #2: GCCTAAGCCTTG (Count: 186)
# length of filtered df: 201
#   > RapidFuzz gathered 201 reads
#   > Sim Stop (Clean): Real=16.8411 < P99=31.5641 after 20 sims.
#   > Sim Stop (Clean): Real=14.6283 < P99=20.9715 after 20 sims.
#   > Suspicious (Real > Threshold). Extending sims... 20/100
#   > Suspicious (Real > Threshold). Extending sims... 40/100
#   > Suspicious (Real > Threshold). Extending sims... 60/100
#   > Suspicious (Real > Threshold). Extending sims... 80/100
# !!! Outlier: Real=54.9662 > P99=8.6286 (Sims: 100)
#   > Splitting cluster (Depth 0) - Size 141
#     > Initial Top Cols found: 405
#     > Split successful: 102 vs 39
#   > Suspicious (Real > Threshold). Extending sims... 20/100
#   > Suspicious (Real > Threshold). Extending sims... 40/100
#   > Suspicious (Real > Threshold). Extending sims... 60/100
#   > Suspicious (Real > Threshold). Extending sims... 80/100
# !!! Outlier: Real=60.9496 > P99=10.5347 (Sims: 100)
#   > Splitting cluster (Depth 1) - Size 102
#     > Initial Top Cols found: 331
#     > Split successful: 63 vs 39
#   > Suspicious (Real > Threshold). Extending sims... 20/100
#   > Suspicious (Real > Threshold). Extending sims... 40/100
#   > Suspicious (Real > Threshold). Extending sims... 60/100
#   > Suspicious (Real > Threshold). Extending sims... 80/100
# !!! Outlier: Real=39.8033 > P99=14.3817 (Sims: 100)
#   > Splitting cluster (Depth 2) - Size 63
#     > Initial Top Cols found: 223
#     > Split successful: 38 vs 25
#   > Sim Stop (Clean): Real=13.2055 < P99=18.8858 after 20 sims.
#   > Sim Stop (Clean): Real=17.7944 < P99=17.9723 after 20 sims.
#   > Sim Stop (Clean): Real=12.9484 < P99=17.1395 after 20 sims.
#   > Sim Stop (Clean): Real=12.9244 < P99=16.9526 after 20 sims.
#
# ========================================
# OPERATION                      | TIME (s)
# -------------------------------------------
# MI_Integrity_Check_Total       | 4.3423
# Sim_Parallel                   | 2.2072
# SPOA_alignment_initial         | 1.5348
# SPOA_alignment                 | 1.1979
# Real_Score                     | 0.8284
# compute_mi_hybrid_execution    | 0.8026
# SPOA_Consensus_Total           | 0.1825
# get_elbow_columns              | 0.0602
# ward_splitting                 | 0.0286
# hamming_distance_matrix        | 0.0197
# Fuzzy_CDIST_Calculations       | 0.0173
# encode_msa                     | 0.0102
# agglomerative_clustering       | 0.0026
# filter_consensus_generation    | 0.0019
# Filter_Invariant               | 0.0012
# ========================================
#
#      ID  cluster  mi_warning  barcodes_consistent  count
# 2  3876        0       False                 True     27
# 1  3376        1       False                 True     33
# 5  5376        2       False                 True     38
# 0   376        3       False                 True     25
# 4  4876        4       False                 True     39
# 3  4376        5       False                 True     39
#
#
# =============
# GCCTTGAGACCG
# Processing Top Barcode #3: GCCTTGAGACCG (Count: 186)
# length of filtered df: 200
#   > RapidFuzz gathered 200 reads
#   > Sim Stop (Clean): Real=18.3205 < P99=18.4740 after 20 sims.
#   > Suspicious (Real > Threshold). Extending sims... 20/100
#   > Suspicious (Real > Threshold). Extending sims... 40/100
#   > Suspicious (Real > Threshold). Extending sims... 60/100
#   > Suspicious (Real > Threshold). Extending sims... 80/100
# !!! Outlier: Real=54.5172 > P99=8.4513 (Sims: 100)
#   > Splitting cluster (Depth 0) - Size 139
#     > Initial Top Cols found: 362
#     > Split successful: 102 vs 37
#   > Suspicious (Real > Threshold). Extending sims... 20/100
#   > Suspicious (Real > Threshold). Extending sims... 40/100
#   > Suspicious (Real > Threshold). Extending sims... 60/100
#   > Suspicious (Real > Threshold). Extending sims... 80/100
# !!! Outlier: Real=41.1054 > P99=10.9229 (Sims: 100)
#   > Splitting cluster (Depth 1) - Size 102
#     > Initial Top Cols found: 292
#     > Split successful: 77 vs 25
#   > Suspicious (Real > Threshold). Extending sims... 20/100
#   > Suspicious (Real > Threshold). Extending sims... 40/100
#   > Suspicious (Real > Threshold). Extending sims... 60/100
#   > Suspicious (Real > Threshold). Extending sims... 80/100
# !!! Outlier: Real=34.9893 > P99=14.7462 (Sims: 100)
#   > Splitting cluster (Depth 2) - Size 77
#     > Initial Top Cols found: 236
#     > Split successful: 37 vs 40
#   > Sim Stop (Clean): Real=13.4334 < P99=25.0632 after 20 sims.
#   > Sim Stop (Clean): Real=12.7547 < P99=24.2952 after 20 sims.
#   > Sim Stop (Clean): Real=17.7944 < P99=21.2325 after 20 sims.
#   > Sim Stop (Clean): Real=13.4294 < P99=21.7415 after 20 sims.
#   > Sim Stop (Clean): Real=13.4629 < P99=19.6314 after 20 sims.
#
# ========================================
# OPERATION                      | TIME (s)
# -------------------------------------------
# MI_Integrity_Check_Total       | 5.3712
# Sim_Parallel                   | 2.5634
# SPOA_alignment_initial         | 2.2339
# SPOA_alignment                 | 1.7418
# Real_Score                     | 0.9421
# compute_mi_hybrid_execution    | 0.8978
# SPOA_Consensus_Total           | 0.4306
# get_elbow_columns              | 0.0879
# ward_splitting                 | 0.0442
# hamming_distance_matrix        | 0.0278
# Fuzzy_CDIST_Calculations       | 0.0251
# encode_msa                     | 0.0143
# filter_consensus_generation    | 0.0048
# agglomerative_clustering       | 0.0041
# Filter_Invariant               | 0.0017
# ========================================
#
#      ID  cluster  mi_warning  barcodes_consistent  count
# 2  3560        0       False                 True     37
# 1  3060        1       False                 True     24
# 3  4060        2       False                 True     37
# 0    60        3       False                 True     40
# 4  4560        4       False                 True     25
# 5  5060        5       False                 True     37
#
#
# =============
# GGCGACGCGAAA
# Processing Top Barcode #4: GGCGACGCGAAA (Count: 185)
# length of filtered df: 207
#   > RapidFuzz gathered 207 reads
#   > Suspicious (Real > Threshold). Extending sims... 20/100
#   > Suspicious (Real > Threshold). Extending sims... 40/100
#   > Suspicious (Real > Threshold). Extending sims... 60/100
#   > Suspicious (Real > Threshold). Extending sims... 80/100
# !!! Outlier: Real=58.2672 > P99=9.7388 (Sims: 100)
#   > Splitting cluster (Depth 0) - Size 106
#     > Initial Top Cols found: 352
#     > Split successful: 69 vs 37
#   > Suspicious (Real > Threshold). Extending sims... 20/100
#   > Suspicious (Real > Threshold). Extending sims... 40/100
#   > Suspicious (Real > Threshold). Extending sims... 60/100
#   > Suspicious (Real > Threshold). Extending sims... 80/100
# !!! Outlier: Real=37.2804 > P99=12.3753 (Sims: 100)
#   > Splitting cluster (Depth 1) - Size 69
#     > Initial Top Cols found: 255
#     > Split successful: 34 vs 35
#   > Sim Stop (Clean): Real=14.3151 < P99=20.9348 after 20 sims.
#   > Sim Stop (Clean): Real=14.0162 < P99=20.4985 after 20 sims.
#   > Sim Stop (Clean): Real=13.4250 < P99=19.2513 after 20 sims.
#   > Sim Stop (Clean): Real=12.9244 < P99=17.0760 after 20 sims.
#   > Sim Stop (Clean): Real=13.1692 < P99=24.2455 after 20 sims.
#   > Sim Stop (Clean): Real=18.3205 < P99=18.5100 after 20 sims.
#
# ========================================
# OPERATION                      | TIME (s)
# -------------------------------------------
# MI_Integrity_Check_Total       | 6.1335
# SPOA_alignment_initial         | 2.8924
# Sim_Parallel                   | 2.7556
# SPOA_alignment                 | 2.2278
# Real_Score                     | 1.0192
# compute_mi_hybrid_execution    | 0.9920
# SPOA_Consensus_Total           | 0.6217
# get_elbow_columns              | 0.1154
# ward_splitting                 | 0.0524
# Fuzzy_CDIST_Calculations       | 0.0392
# hamming_distance_matrix        | 0.0373
# encode_msa                     | 0.0201
# filter_consensus_generation    | 0.0066
# agglomerative_clustering       | 0.0049
# Filter_Invariant               | 0.0020
# ========================================
#
#      ID  cluster  mi_warning  barcodes_consistent  count
# 4  4867        0       False                 True     39
# 1  3367        1       False                 True     38
# 2  3867        2       False                 True     24
# 3  4367        3       False                 True     34
# 0   367        4       False                 True     35
# 5  5367        5       False                 True     37
#
#
# =============
# GTTGGATTATAA
# Processing Top Barcode #5: GTTGGATTATAA (Count: 183)
# length of filtered df: 206
#   > RapidFuzz gathered 206 reads
#   > Suspicious (Real > Threshold). Extending sims... 20/100
#   > Suspicious (Real > Threshold). Extending sims... 40/100
#   > Suspicious (Real > Threshold). Extending sims... 60/100
#   > Suspicious (Real > Threshold). Extending sims... 80/100
# !!! Outlier: Real=52.2028 > P99=9.0315 (Sims: 100)
#   > Splitting cluster (Depth 0) - Size 127
#     > Initial Top Cols found: 346
#     > Split successful: 91 vs 36
#   > Suspicious (Real > Threshold). Extending sims... 20/100
#   > Suspicious (Real > Threshold). Extending sims... 40/100
#   > Suspicious (Real > Threshold). Extending sims... 60/100
#   > Suspicious (Real > Threshold). Extending sims... 80/100
# !!! Outlier: Real=52.4811 > P99=10.5490 (Sims: 100)
#   > Splitting cluster (Depth 1) - Size 91
#     > Initial Top Cols found: 285
#     > Split successful: 53 vs 38
#   > Suspicious (Real > Threshold). Extending sims... 20/100
#   > Suspicious (Real > Threshold). Extending sims... 40/100
#   > Suspicious (Real > Threshold). Extending sims... 60/100
#   > Suspicious (Real > Threshold). Extending sims... 80/100
# !!! Outlier: Real=20.8360 > P99=15.0405 (Sims: 100)
#   > Splitting cluster (Depth 2) - Size 53
#     > Initial Top Cols found: 178
#     > Split successful: 38 vs 15
#   > Sim Stop (Clean): Real=13.2052 < P99=20.8236 after 20 sims.
#   > Sim Stop (Clean): Real=25.4930 < P99=37.5578 after 20 sims.
#   > Sim Stop (Clean): Real=13.1689 < P99=18.7818 after 20 sims.
#   > Sim Stop (Clean): Real=15.1322 < P99=26.3067 after 20 sims.
#   > Sim Stop (Clean): Real=12.6906 < P99=18.4858 after 20 sims.
#   > Sim Stop (Clean): Real=12.9243 < P99=13.0652 after 20 sims.
#
# ========================================
# OPERATION                      | TIME (s)
# -------------------------------------------
# MI_Integrity_Check_Total       | 7.1336
# SPOA_alignment_initial         | 3.6812
# Sim_Parallel                   | 3.0512
# SPOA_alignment                 | 2.8194
# compute_mi_hybrid_execution    | 1.1629
# Real_Score                     | 1.1200
# SPOA_Consensus_Total           | 0.8554
# get_elbow_columns              | 0.1495
# ward_splitting                 | 0.0650
# Fuzzy_CDIST_Calculations       | 0.0483
# hamming_distance_matrix        | 0.0469
# encode_msa                     | 0.0254
# filter_consensus_generation    | 0.0085
# agglomerative_clustering       | 0.0058
# Filter_Invariant               | 0.0024
# ========================================
#
#      ID  cluster  mi_warning  barcodes_consistent  count
# 2  3857        0       False                 True     40
# 1  3357        1       False                 True     39
# 4  4857        2       False                 True     38
# 0   357        3       False                 True     15
# 5  5357        4       False                 True     38
# 3  4357        5       False                 True     36
#
#
# =============
# CAAGAAGCAAAT
# Processing Top Barcode #6: CAAGAAGCAAAT (Count: 183)
# length of filtered df: 202
#   > RapidFuzz gathered 202 reads
#   > Suspicious (Real > Threshold). Extending sims... 20/100
#   > Suspicious (Real > Threshold). Extending sims... 40/100
#   > Suspicious (Real > Threshold). Extending sims... 60/100
#   > Suspicious (Real > Threshold). Extending sims... 80/100
# !!! Outlier: Real=55.4125 > P99=9.8409 (Sims: 100)
#   > Splitting cluster (Depth 0) - Size 132
#     > Initial Top Cols found: 295
#     > Split successful: 96 vs 36
#   > Suspicious (Real > Threshold). Extending sims... 20/100
#   > Suspicious (Real > Threshold). Extending sims... 40/100
#   > Suspicious (Real > Threshold). Extending sims... 60/100
#   > Suspicious (Real > Threshold). Extending sims... 80/100
# !!! Outlier: Real=62.2797 > P99=12.4835 (Sims: 100)
#   > Splitting cluster (Depth 1) - Size 96
#     > Initial Top Cols found: 234
#     > Split successful: 60 vs 36
#   > Suspicious (Real > Threshold). Extending sims... 20/100
#   > Suspicious (Real > Threshold). Extending sims... 40/100
#   > Suspicious (Real > Threshold). Extending sims... 60/100
#   > Suspicious (Real > Threshold). Extending sims... 80/100
# !!! Outlier: Real=68.4696 > P99=17.8276 (Sims: 100)
#   > Splitting cluster (Depth 2) - Size 60
#     > Initial Top Cols found: 158
#     > Split successful: 30 vs 30
#   > Sim Stop (Clean): Real=15.6145 < P99=29.2360 after 20 sims.
#   > Sim Stop (Clean): Real=15.6145 < P99=30.1140 after 20 sims.
#   > Sim Stop (Clean): Real=13.7576 < P99=22.4559 after 20 sims.
#   > Sim Stop (Clean): Real=13.6931 < P99=25.5751 after 20 sims.
#   > Sim Stop (Clean): Real=14.2691 < P99=26.6744 after 20 sims.
#   > Sim Stop (Clean): Real=14.0604 < P99=26.8641 after 20 sims.
#
# ========================================
# OPERATION                      | TIME (s)
# -------------------------------------------
# MI_Integrity_Check_Total       | 7.8523
# SPOA_alignment_initial         | 4.2233
# Sim_Parallel                   | 3.2776
# SPOA_alignment                 | 3.2174
# compute_mi_hybrid_execution    | 1.2445
# Real_Score                     | 1.2038
# SPOA_Consensus_Total           | 1.0906
# get_elbow_columns              | 0.1759
# ward_splitting                 | 0.0770
# Fuzzy_CDIST_Calculations       | 0.0573
# hamming_distance_matrix        | 0.0554
# encode_msa                     | 0.0292
# filter_consensus_generation    | 0.0103
# agglomerative_clustering       | 0.0066
# Filter_Invariant               | 0.0028
# ========================================
#
#      ID  cluster  mi_warning  barcodes_consistent  count
# 2  3935        0       False                 True     34
# 1  3435        1       False                 True     35
# 3  4435        2       False                 True     30
# 0   435        3       False                 True     30
# 4  4935        4       False                 True     36
# 5  5435        5       False                 True     36
#
#
# =============
# TAGAGTACTCAC
# Processing Top Barcode #7: TAGAGTACTCAC (Count: 180)
# length of filtered df: 198
#   > RapidFuzz gathered 198 reads
#   > Suspicious (Real > Threshold). Extending sims... 20/100
#   > Suspicious (Real > Threshold). Extending sims... 40/100
#   > Suspicious (Real > Threshold). Extending sims... 60/100
#   > Suspicious (Real > Threshold). Extending sims... 80/100
# !!! Outlier: Real=49.2302 > P99=9.7628 (Sims: 100)
#   > Splitting cluster (Depth 0) - Size 134
#     > Initial Top Cols found: 266
#     > Split successful: 99 vs 35
#   > Suspicious (Real > Threshold). Extending sims... 20/100
#   > Suspicious (Real > Threshold). Extending sims... 40/100
#   > Suspicious (Real > Threshold). Extending sims... 60/100
#   > Suspicious (Real > Threshold). Extending sims... 80/100
# !!! Outlier: Real=57.2845 > P99=12.1967 (Sims: 100)
#   > Splitting cluster (Depth 1) - Size 99
#     > Initial Top Cols found: 193
#     > Split successful: 72 vs 27
#   > Suspicious (Real > Threshold). Extending sims... 20/100
#   > Suspicious (Real > Threshold). Extending sims... 40/100
#   > Suspicious (Real > Threshold). Extending sims... 60/100
#   > Suspicious (Real > Threshold). Extending sims... 80/100
# !!! Outlier: Real=36.8702 > P99=15.5679 (Sims: 100)
#   > Splitting cluster (Depth 2) - Size 72
#     > Initial Top Cols found: 140
#     > Split successful: 38 vs 34
#   > Sim Stop (Clean): Real=13.1692 < P99=25.2483 after 20 sims.
#   > Sim Stop (Clean): Real=14.2691 < P99=21.6598 after 20 sims.
#   > Sim Stop (Clean): Real=16.8411 < P99=17.1143 after 20 sims.
#   > Sim Stop (Clean): Real=14.0594 < P99=21.2746 after 20 sims.
#   > Sim Stop (Clean): Real=12.7399 < P99=23.3914 after 20 sims.
#   > Sim Stop (Clean): Real=18.3205 < P99=18.6708 after 20 sims.
#
# ========================================
# OPERATION                      | TIME (s)
# -------------------------------------------
# MI_Integrity_Check_Total       | 8.5037
# SPOA_alignment_initial         | 4.6796
# SPOA_alignment                 | 3.5662
# Sim_Parallel                   | 3.4972
# compute_mi_hybrid_execution    | 1.2927
# Real_Score                     | 1.2750
# SPOA_Consensus_Total           | 1.2532
# get_elbow_columns              | 0.1931
# ward_splitting                 | 0.0876
# Fuzzy_CDIST_Calculations       | 0.0657
# hamming_distance_matrix        | 0.0622
# encode_msa                     | 0.0336
# filter_consensus_generation    | 0.0123
# agglomerative_clustering       | 0.0080
# Filter_Invariant               | 0.0031
# ========================================
#
#      ID  cluster  mi_warning  barcodes_consistent  count
# 2  3994        0       False                 True     40
# 1  3494        1       False                 True     24
# 4  4994        2       False                 True     38
# 0   494        3       False                 True     34
# 3  4494        4       False                 True     27
# 5  5494        5       False                 True     35
#
#
# =============
# TCAGAAGAAGGG
# Processing Top Barcode #8: TCAGAAGAAGGG (Count: 180)
# length of filtered df: 198
#   > RapidFuzz gathered 198 reads
#   > Sim Stop (Clean): Real=16.4076 < P99=23.6306 after 20 sims.
#   > Suspicious (Real > Threshold). Extending sims... 20/100
#   > Suspicious (Real > Threshold). Extending sims... 40/100
#   > Suspicious (Real > Threshold). Extending sims... 60/100
#   > Suspicious (Real > Threshold). Extending sims... 80/100
# !!! Outlier: Real=58.4895 > P99=9.8425 (Sims: 100)
#   > Splitting cluster (Depth 0) - Size 132
#     > Initial Top Cols found: 271
#     > Split successful: 92 vs 40
#   > Suspicious (Real > Threshold). Extending sims... 20/100
#   > Suspicious (Real > Threshold). Extending sims... 40/100
#   > Suspicious (Real > Threshold). Extending sims... 60/100
#   > Suspicious (Real > Threshold). Extending sims... 80/100
# !!! Outlier: Real=56.4628 > P99=12.9830 (Sims: 100)
#   > Splitting cluster (Depth 1) - Size 92
#     > Initial Top Cols found: 213
#     > Split successful: 68 vs 24
#   > Suspicious (Real > Threshold). Extending sims... 20/100
#   > Suspicious (Real > Threshold). Extending sims... 40/100
#   > Suspicious (Real > Threshold). Extending sims... 60/100
#   > Suspicious (Real > Threshold). Extending sims... 80/100
# !!! Outlier: Real=37.9673 > P99=16.1847 (Sims: 100)
#   > Splitting cluster (Depth 2) - Size 68
#     > Initial Top Cols found: 162
#     > Split successful: 40 vs 28
#   > Sim Stop (Clean): Real=12.6907 < P99=23.6588 after 20 sims.
#   > Sim Stop (Clean): Real=16.4076 < P99=17.1706 after 20 sims.
#   > Sim Stop (Clean): Real=18.3205 < P99=18.7085 after 20 sims.
#   > Sim Stop (Clean): Real=12.6907 < P99=24.3173 after 20 sims.
#   > Sim Stop (Clean): Real=13.5206 < P99=20.4391 after 20 sims.
#
# ========================================
# OPERATION                      | TIME (s)
# -------------------------------------------
# MI_Integrity_Check_Total       | 9.2432
# SPOA_alignment_initial         | 5.2489
# SPOA_alignment                 | 3.9778
# Sim_Parallel                   | 3.7390
# SPOA_Consensus_Total           | 1.3849
# compute_mi_hybrid_execution    | 1.3794
# Real_Score                     | 1.3498
# get_elbow_columns              | 0.2168
# ward_splitting                 | 0.0981
# Fuzzy_CDIST_Calculations       | 0.0741
# hamming_distance_matrix        | 0.0706
# encode_msa                     | 0.0384
# filter_consensus_generation    | 0.0140
# agglomerative_clustering       | 0.0090
# Filter_Invariant               | 0.0035
# ========================================
#
#      ID  cluster  mi_warning  barcodes_consistent  count
# 2  3538        0       False                 True     28
# 1  3038        1       False                 True     37
# 0    38        2       False                 True     40
# 5  5038        3       False                 True     28
# 3  4038        4       False                 True     24
# 4  4538        5       False                 True     40
#
#
# =============
# CCAACCACGTCT
# Processing Top Barcode #9: CCAACCACGTCT (Count: 180)
# length of filtered df: 196
#   > RapidFuzz gathered 196 reads
#   > Suspicious (Real > Threshold). Extending sims... 20/100
#   > Suspicious (Real > Threshold). Extending sims... 40/100
#   > Suspicious (Real > Threshold). Extending sims... 60/100
#   > Suspicious (Real > Threshold). Extending sims... 80/100
# !!! Outlier: Real=53.7999 > P99=8.8008 (Sims: 100)
#   > Splitting cluster (Depth 0) - Size 132
#     > Initial Top Cols found: 430
#     > Split successful: 94 vs 38
#   > Suspicious (Real > Threshold). Extending sims... 20/100
#   > Suspicious (Real > Threshold). Extending sims... 40/100
#   > Suspicious (Real > Threshold). Extending sims... 60/100
#   > Suspicious (Real > Threshold). Extending sims... 80/100
# !!! Outlier: Real=61.1022 > P99=11.9483 (Sims: 100)
#   > Splitting cluster (Depth 1) - Size 94
#     > Initial Top Cols found: 329
#     > Split successful: 60 vs 34
#   > Suspicious (Real > Threshold). Extending sims... 20/100
#   > Suspicious (Real > Threshold). Extending sims... 40/100
#   > Suspicious (Real > Threshold). Extending sims... 60/100
#   > Suspicious (Real > Threshold). Extending sims... 80/100
# !!! Outlier: Real=60.7192 > P99=13.6770 (Sims: 100)
#   > Splitting cluster (Depth 2) - Size 60
#     > Initial Top Cols found: 236
#     > Split successful: 20 vs 40
#   > Sim Stop (Clean): Real=21.1294 < P99=26.1741 after 20 sims.
#   > Sim Stop (Clean): Real=12.7227 < P99=18.5306 after 20 sims.
#   > Sim Stop (Clean): Real=14.2691 < P99=20.4733 after 20 sims.
#   > Sim Stop (Clean): Real=14.9023 < P99=18.8492 after 20 sims.
#   > Sim Stop (Clean): Real=17.7944 < P99=28.8769 after 20 sims.
#   > Sim Stop (Clean): Real=12.9940 < P99=24.7819 after 20 sims.
#
# ========================================
# OPERATION                      | TIME (s)
# -------------------------------------------
# MI_Integrity_Check_Total       | 10.4254
# SPOA_alignment_initial         | 6.1011
# SPOA_alignment                 | 4.6468
# Sim_Parallel                   | 4.1179
# SPOA_Consensus_Total           | 1.5465
# compute_mi_hybrid_execution    | 1.5019
# Real_Score                     | 1.4688
# get_elbow_columns              | 0.2513
# ward_splitting                 | 0.1125
# Fuzzy_CDIST_Calculations       | 0.0842
# hamming_distance_matrix        | 0.0792
# encode_msa                     | 0.0483
# filter_consensus_generation    | 0.0159
# agglomerative_clustering       | 0.0097
# Filter_Invariant               | 0.0041
# ========================================
#
#      ID  cluster  mi_warning  barcodes_consistent  count
# 2  3655        0       False                 True     25
# 1  3155        1       False                 True     39
# 4  4655        2       False                 True     20
# 0   155        3       False                 True     40
# 5  5155        4       False                 True     34
# 3  4155        5       False                 True     38
#
#
# =============
# GAACAAAACCTA
# Processing Top Barcode #10: GAACAAAACCTA (Count: 179)
# length of filtered df: 196
#   > RapidFuzz gathered 196 reads
#   > Sim Stop (Clean): Real=13.2408 < P99=21.6192 after 20 sims.
#   > Suspicious (Real > Threshold). Extending sims... 20/100
#   > Suspicious (Real > Threshold). Extending sims... 40/100
#   > Suspicious (Real > Threshold). Extending sims... 60/100
#   > Suspicious (Real > Threshold). Extending sims... 80/100
# !!! Outlier: Real=56.6382 > P99=10.0475 (Sims: 100)
#   > Splitting cluster (Depth 0) - Size 129
#     > Initial Top Cols found: 256
#     > Split successful: 91 vs 38
#   > Suspicious (Real > Threshold). Extending sims... 20/100
#   > Suspicious (Real > Threshold). Extending sims... 40/100
#   > Suspicious (Real > Threshold). Extending sims... 60/100
#   > Suspicious (Real > Threshold). Extending sims... 80/100
# !!! Outlier: Real=48.3640 > P99=12.9961 (Sims: 100)
#   > Splitting cluster (Depth 1) - Size 91
#     > Initial Top Cols found: 192
#     > Split successful: 73 vs 18
#   > Suspicious (Real > Threshold). Extending sims... 20/100
#   > Suspicious (Real > Threshold). Extending sims... 40/100
#   > Suspicious (Real > Threshold). Extending sims... 60/100
#   > Suspicious (Real > Threshold). Extending sims... 80/100
# !!! Outlier: Real=36.9511 > P99=15.3288 (Sims: 100)
#   > Splitting cluster (Depth 2) - Size 73
#     > Initial Top Cols found: 163
#     > Split successful: 36 vs 37
#   > Sim Stop (Clean): Real=13.8428 < P99=22.4559 after 20 sims.
#   > Sim Stop (Clean): Real=13.4251 < P99=25.7751 after 20 sims.
#   > Sim Stop (Clean): Real=22.4559 < P99=22.8034 after 20 sims.
#   > Sim Stop (Clean): Real=13.1692 < P99=25.2673 after 20 sims.
#   > Sim Stop (Clean): Real=15.9995 < P99=29.6117 after 20 sims.
#
# ========================================
# OPERATION                      | TIME (s)
# -------------------------------------------
# MI_Integrity_Check_Total       | 11.0402
# SPOA_alignment_initial         | 6.5421
# SPOA_alignment                 | 4.9727
# Sim_Parallel                   | 4.3227
# SPOA_Consensus_Total           | 1.7838
# compute_mi_hybrid_execution    | 1.5730
# Real_Score                     | 1.5431
# get_elbow_columns              | 0.2699
# ward_splitting                 | 0.1222
# Fuzzy_CDIST_Calculations       | 0.0987
# hamming_distance_matrix        | 0.0870
# encode_msa                     | 0.0511
# filter_consensus_generation    | 0.0180
# agglomerative_clustering       | 0.0106
# Filter_Invariant               | 0.0044
# ========================================
#
#      ID  cluster  mi_warning  barcodes_consistent  count
# 2  3850        0       False                 True     38
# 1  3350        1       False                 True     29
# 0   350        2       False                 True     36
# 5  5350        3       False                 True     37
# 4  4850        4       False                 True     18
# 3  4350        5       False                 True     38
#
#
# =============
# GCCACGTGAACT
# Processing Top Barcode #11: GCCACGTGAACT (Count: 179)
# length of filtered df: 192
#   > RapidFuzz gathered 192 reads
#   > Sim Stop (Clean): Real=17.3125 < P99=21.6229 after 20 sims.
#   > Sim Stop (Clean): Real=14.2343 < P99=21.3855 after 20 sims.
#   > Suspicious (Real > Threshold). Extending sims... 20/100
#   > Suspicious (Real > Threshold). Extending sims... 40/100
#   > Suspicious (Real > Threshold). Extending sims... 60/100
#   > Suspicious (Real > Threshold). Extending sims... 80/100
# !!! Outlier: Real=58.5335 > P99=10.6557 (Sims: 100)
#   > Splitting cluster (Depth 0) - Size 119
#     > Initial Top Cols found: 285
#     > Split successful: 81 vs 38
#   > Suspicious (Real > Threshold). Extending sims... 20/100
#   > Suspicious (Real > Threshold). Extending sims... 40/100
#   > Suspicious (Real > Threshold). Extending sims... 60/100
#   > Suspicious (Real > Threshold). Extending sims... 80/100
# !!! Outlier: Real=59.3526 > P99=14.2309 (Sims: 100)
#   > Splitting cluster (Depth 1) - Size 81
#     > Initial Top Cols found: 217
#     > Split successful: 59 vs 22
#   > Suspicious (Real > Threshold). Extending sims... 20/100
#   > Suspicious (Real > Threshold). Extending sims... 40/100
#   > Suspicious (Real > Threshold). Extending sims... 60/100
#   > Suspicious (Real > Threshold). Extending sims... 80/100
# !!! Outlier: Real=66.7425 > P99=18.0342 (Sims: 100)
#   > Splitting cluster (Depth 2) - Size 59
#     > Initial Top Cols found: 159
#     > Split successful: 30 vs 29
#   > Sim Stop (Clean): Real=15.6145 < P99=23.6622 after 20 sims.
#   > Sim Stop (Clean): Real=16.1272 < P99=29.9675 after 20 sims.
#   > Sim Stop (Clean): Real=19.4907 < P99=34.3360 after 20 sims.
#   > Sim Stop (Clean): Real=13.2423 < P99=21.6192 after 20 sims.
#
# ========================================
# OPERATION                      | TIME (s)
# -------------------------------------------
# MI_Integrity_Check_Total       | 11.7661
# SPOA_alignment_initial         | 7.0682
# SPOA_alignment                 | 5.3749
# Sim_Parallel                   | 4.5491
# SPOA_Consensus_Total           | 1.9123
# compute_mi_hybrid_execution    | 1.6503
# Real_Score                     | 1.6298
# get_elbow_columns              | 0.2929
# ward_splitting                 | 0.1311
# Fuzzy_CDIST_Calculations       | 0.1104
# hamming_distance_matrix        | 0.0942
# encode_msa                     | 0.0556
# filter_consensus_generation    | 0.0199
# agglomerative_clustering       | 0.0117
# Filter_Invariant               | 0.0048
# ========================================
#
#      ID  cluster  mi_warning  barcodes_consistent  count
# 2  3769        0       False                 True     36
# 1  3269        1       False                 True     37
# 0   269        2       False                 True     30
# 5  5269        3       False                 True     29
# 3  4269        4       False                 True     22
# 4  4769        5       False                 True     38
#
#
# =============
# AGCATGACTATT
# Processing Top Barcode #12: AGCATGACTATT (Count: 179)
# length of filtered df: 185
#   > RapidFuzz gathered 185 reads
#   > Sim Stop (Clean): Real=20.1444 < P99=30.2625 after 20 sims.
#   > Sim Stop (Clean): Real=18.4153 < P99=23.3735 after 20 sims.
#   > Suspicious (Real > Threshold). Extending sims... 20/100
#   > Suspicious (Real > Threshold). Extending sims... 40/100
#   > Suspicious (Real > Threshold). Extending sims... 60/100
#   > Suspicious (Real > Threshold). Extending sims... 80/100
# !!! Outlier: Real=52.9898 > P99=8.4636 (Sims: 100)
#   > Splitting cluster (Depth 0) - Size 140
#     > Initial Top Cols found: 395
#     > Split successful: 106 vs 34
#   > Suspicious (Real > Threshold). Extending sims... 20/100
#   > Suspicious (Real > Threshold). Extending sims... 40/100
#   > Suspicious (Real > Threshold). Extending sims... 60/100
#   > Suspicious (Real > Threshold). Extending sims... 80/100
# !!! Outlier: Real=59.9775 > P99=9.6128 (Sims: 100)
#   > Splitting cluster (Depth 1) - Size 106
#     > Initial Top Cols found: 325
#     > Split successful: 71 vs 35
#   > Suspicious (Real > Threshold). Extending sims... 20/100
#   > Suspicious (Real > Threshold). Extending sims... 40/100
#   > Suspicious (Real > Threshold). Extending sims... 60/100
#   > Suspicious (Real > Threshold). Extending sims... 80/100
# !!! Outlier: Real=38.9551 > P99=13.3423 (Sims: 100)
#   > Splitting cluster (Depth 2) - Size 71
#     > Initial Top Cols found: 226
#     > Split successful: 40 vs 31
#   > Sim Stop (Clean): Real=12.6907 < P99=18.6024 after 20 sims.
#   > Sim Stop (Clean): Real=15.2506 < P99=21.9423 after 20 sims.
#   > Sim Stop (Clean): Real=13.9741 < P99=18.5266 after 20 sims.
#   > Sim Stop (Clean): Real=14.2691 < P99=16.6627 after 20 sims.
#
# ========================================
# OPERATION                      | TIME (s)
# -------------------------------------------
# MI_Integrity_Check_Total       | 13.0465
# SPOA_alignment_initial         | 7.9698
# SPOA_alignment                 | 6.0873
# Sim_Parallel                   | 4.9811
# SPOA_Consensus_Total           | 2.0713
# compute_mi_hybrid_execution    | 1.7685
# Real_Score                     | 1.7498
# get_elbow_columns              | 0.3257
# ward_splitting                 | 0.1482
# Fuzzy_CDIST_Calculations       | 0.1197
# hamming_distance_matrix        | 0.1026
# encode_msa                     | 0.0617
# filter_consensus_generation    | 0.0217
# agglomerative_clustering       | 0.0125
# Filter_Invariant               | 0.0053
# ========================================
#
#      ID  cluster  mi_warning  barcodes_consistent  count
# 2  3982        0       False                 True     21
# 1  3482        1       False                 True     24
# 5  5482        2       False                 True     40
# 0   482        3       False                 True     31
# 3  4482        4       False                 True     35
# 4  4982        5       False                 True     34
#
#
# =============
# CGTTATACGTGT
# Processing Top Barcode #13: CGTTATACGTGT (Count: 179)
# length of filtered df: 203
#   > RapidFuzz gathered 203 reads
#   > Sim Stop (Clean): Real=16.4076 < P99=31.6829 after 20 sims.
#   > Suspicious (Real > Threshold). Extending sims... 20/100
#   > Suspicious (Real > Threshold). Extending sims... 40/100
#   > Suspicious (Real > Threshold). Extending sims... 60/100
#   > Suspicious (Real > Threshold). Extending sims... 80/100
# !!! Outlier: Real=54.5736 > P99=9.1464 (Sims: 100)
#   > Splitting cluster (Depth 0) - Size 134
#     > Initial Top Cols found: 406
#     > Split successful: 98 vs 36
#   > Suspicious (Real > Threshold). Extending sims... 20/100
#   > Suspicious (Real > Threshold). Extending sims... 40/100
#   > Suspicious (Real > Threshold). Extending sims... 60/100
#   > Suspicious (Real > Threshold). Extending sims... 80/100
# !!! Outlier: Real=36.9760 > P99=11.5700 (Sims: 100)
#   > Splitting cluster (Depth 1) - Size 98
#     > Initial Top Cols found: 323
#     > Split successful: 68 vs 30
#   > Suspicious (Real > Threshold). Extending sims... 20/100
#   > Suspicious (Real > Threshold). Extending sims... 40/100
#   > Suspicious (Real > Threshold). Extending sims... 60/100
#   > Suspicious (Real > Threshold). Extending sims... 80/100
# !!! Outlier: Real=48.8911 > P99=16.1480 (Sims: 100)
#   > Splitting cluster (Depth 2) - Size 68
#     > Initial Top Cols found: 240
#     > Split successful: 40 vs 28
#   > Sim Stop (Clean): Real=12.7176 < P99=18.1949 after 20 sims.
#   > Sim Stop (Clean): Real=16.4076 < P99=20.6156 after 20 sims.
#   > Sim Stop (Clean): Real=15.6145 < P99=22.9738 after 20 sims.
#   > Sim Stop (Clean): Real=13.6924 < P99=20.0374 after 20 sims.
#   > Sim Stop (Clean): Real=12.6904 < P99=23.7135 after 20 sims.
#
# ========================================
# OPERATION                      | TIME (s)
# -------------------------------------------
# MI_Integrity_Check_Total       | 14.2479
# SPOA_alignment_initial         | 8.8356
# SPOA_alignment                 | 6.7565
# Sim_Parallel                   | 5.3701
# SPOA_Consensus_Total           | 2.3009
# compute_mi_hybrid_execution    | 1.8845
# Real_Score                     | 1.8795
# get_elbow_columns              | 0.3618
# ward_splitting                 | 0.1641
# Fuzzy_CDIST_Calculations       | 0.1282
# hamming_distance_matrix        | 0.1123
# encode_msa                     | 0.0683
# filter_consensus_generation    | 0.0240
# agglomerative_clustering       | 0.0141
# Filter_Invariant               | 0.0058
# ========================================
#
#      ID  cluster  mi_warning  barcodes_consistent  count
# 1  3113        0       False                 True     40
# 2  3613        1       False                 True     28
# 0   113        2       False                 True     40
# 5  5113        3       False                 True     28
# 4  4613        4       False                 True     30
# 3  4113        5       False                 True     36
#
#
# =============
# AGGGCCTGGATG
# Processing Top Barcode #14: AGGGCCTGGATG (Count: 178)
# length of filtered df: 191
#   > RapidFuzz gathered 191 reads
#   > Sim Stop (Clean): Real=13.2151 < P99=17.4612 after 20 sims.
#   > Suspicious (Real > Threshold). Extending sims... 20/100
#   > Suspicious (Real > Threshold). Extending sims... 40/100
#   > Suspicious (Real > Threshold). Extending sims... 60/100
#   > Suspicious (Real > Threshold). Extending sims... 80/100
# !!! Outlier: Real=58.3896 > P99=10.8752 (Sims: 100)
#   > Splitting cluster (Depth 0) - Size 116
#     > Initial Top Cols found: 264
#     > Split successful: 78 vs 38
#   > Suspicious (Real > Threshold). Extending sims... 20/100
#   > Suspicious (Real > Threshold). Extending sims... 40/100
#   > Suspicious (Real > Threshold). Extending sims... 60/100
#   > Suspicious (Real > Threshold). Extending sims... 80/100
# !!! Outlier: Real=50.2385 > P99=14.6443 (Sims: 100)
#   > Splitting cluster (Depth 1) - Size 78
#     > Initial Top Cols found: 197
#     > Split successful: 49 vs 29
#   > Suspicious (Real > Threshold). Extending sims... 20/100
#   > Suspicious (Real > Threshold). Extending sims... 40/100
#   > Suspicious (Real > Threshold). Extending sims... 60/100
#   > Suspicious (Real > Threshold). Extending sims... 80/100
# !!! Outlier: Real=57.5921 > P99=20.8822 (Sims: 100)
#   > Splitting cluster (Depth 2) - Size 49
#     > Initial Top Cols found: 144
#     > Split successful: 29 vs 20
#   > Sim Stop (Clean): Real=15.9995 < P99=19.4978 after 20 sims.
#   > Sim Stop (Clean): Real=20.8515 < P99=31.2122 after 20 sims.
#   > Sim Stop (Clean): Real=16.0135 < P99=26.0955 after 20 sims.
#   > Sim Stop (Clean): Real=13.1692 < P99=24.5454 after 20 sims.
#   > Sim Stop (Clean): Real=13.4251 < P99=25.7751 after 20 sims.
#
# ========================================
# OPERATION                      | TIME (s)
# -------------------------------------------
# MI_Integrity_Check_Total       | 14.8930
# SPOA_alignment_initial         | 9.3493
# SPOA_alignment                 | 7.1247
# Sim_Parallel                   | 5.5686
# SPOA_Consensus_Total           | 2.5317
# compute_mi_hybrid_execution    | 1.9536
# Real_Score                     | 1.9459
# get_elbow_columns              | 0.3861
# ward_splitting                 | 0.1719
# Fuzzy_CDIST_Calculations       | 0.1367
# hamming_distance_matrix        | 0.1202
# encode_msa                     | 0.0758
# filter_consensus_generation    | 0.0265
# agglomerative_clustering       | 0.0150
# Filter_Invariant               | 0.0064
# ========================================
#
#      ID  cluster  mi_warning  barcodes_consistent  count
# 2  3699        0       False                 True     38
# 1  3199        1       False                 True     37
# 0   199        2       False                 True     29
# 4  4699        3       False                 True     20
# 5  5199        4       False                 True     29
# 3  4199        5       False                 True     38
#
#
# =============
# GGCGTCAGTCCT
# Processing Top Barcode #15: GGCGTCAGTCCT (Count: 177)
# length of filtered df: 199
#   > RapidFuzz gathered 199 reads
#   > Sim Stop (Clean): Real=20.1444 < P99=20.3952 after 20 sims.
#   > Sim Stop (Clean): Real=15.2506 < P99=23.1272 after 20 sims.
#   > Suspicious (Real > Threshold). Extending sims... 20/100
#   > Suspicious (Real > Threshold). Extending sims... 40/100
#   > Suspicious (Real > Threshold). Extending sims... 60/100
#   > Suspicious (Real > Threshold). Extending sims... 80/100
# !!! Outlier: Real=54.3237 > P99=9.0922 (Sims: 100)
#   > Splitting cluster (Depth 0) - Size 147
#     > Initial Top Cols found: 286
#     > Split successful: 108 vs 39
#   > Suspicious (Real > Threshold). Extending sims... 20/100
#   > Suspicious (Real > Threshold). Extending sims... 40/100
#   > Suspicious (Real > Threshold). Extending sims... 60/100
#   > Suspicious (Real > Threshold). Extending sims... 80/100
# !!! Outlier: Real=60.1460 > P99=11.4294 (Sims: 100)
#   > Splitting cluster (Depth 1) - Size 108
#     > Initial Top Cols found: 228
#     > Split successful: 69 vs 39
#   > Suspicious (Real > Threshold). Extending sims... 20/100
#   > Suspicious (Real > Threshold). Extending sims... 40/100
#   > Suspicious (Real > Threshold). Extending sims... 60/100
#   > Suspicious (Real > Threshold). Extending sims... 80/100
# !!! Outlier: Real=38.7594 > P99=15.9924 (Sims: 100)
#   > Splitting cluster (Depth 2) - Size 69
#     > Initial Top Cols found: 171
#     > Split successful: 31 vs 38
#   > Sim Stop (Clean): Real=15.2503 < P99=28.5440 after 20 sims.
#   > Sim Stop (Clean): Real=13.2053 < P99=16.1524 after 20 sims.
#   > Sim Stop (Clean): Real=12.9786 < P99=24.1065 after 20 sims.
#   > Sim Stop (Clean): Real=12.9244 < P99=20.3040 after 20 sims.
#
# ========================================
# OPERATION                      | TIME (s)
# -------------------------------------------
# MI_Integrity_Check_Total       | 15.5491
# SPOA_alignment_initial         | 9.7890
# SPOA_alignment                 | 7.4591
# Sim_Parallel                   | 5.7884
# SPOA_Consensus_Total           | 2.7000
# Real_Score                     | 2.0330
# compute_mi_hybrid_execution    | 2.0225
# get_elbow_columns              | 0.4046
# ward_splitting                 | 0.1861
# Fuzzy_CDIST_Calculations       | 0.1454
# hamming_distance_matrix        | 0.1268
# encode_msa                     | 0.0802
# filter_consensus_generation    | 0.0282
# agglomerative_clustering       | 0.0158
# Filter_Invariant               | 0.0068
# ========================================
#
#      ID  cluster  mi_warning  barcodes_consistent  count
# 2  3736        0       False                 True     21
# 1  3236        1       False                 True     31
# 0   236        2       False                 True     31
# 5  5236        3       False                 True     38
# 4  4736        4       False                 True     39
# 3  4236        5       False                 True     39
#
#
# =============
# TCTTCCGGTAAT
# Processing Top Barcode #16: TCTTCCGGTAAT (Count: 177)
# length of filtered df: 204
#   > RapidFuzz gathered 204 reads
#   > Suspicious (Real > Threshold). Extending sims... 20/100
#   > Suspicious (Real > Threshold). Extending sims... 40/100
#   > Suspicious (Real > Threshold). Extending sims... 60/100
#   > Suspicious (Real > Threshold). Extending sims... 80/100
# !!! Outlier: Real=56.4617 > P99=9.3404 (Sims: 100)
#   > Splitting cluster (Depth 0) - Size 127
#     > Initial Top Cols found: 340
#     > Split successful: 90 vs 37
#   > Suspicious (Real > Threshold). Extending sims... 20/100
#   > Suspicious (Real > Threshold). Extending sims... 40/100
#   > Suspicious (Real > Threshold). Extending sims... 60/100
#   > Suspicious (Real > Threshold). Extending sims... 80/100
# !!! Outlier: Real=63.4338 > P99=10.7778 (Sims: 100)
#   > Splitting cluster (Depth 1) - Size 90
#     > Initial Top Cols found: 261
#     > Split successful: 54 vs 36
#   > Suspicious (Real > Threshold). Extending sims... 20/100
#   > Suspicious (Real > Threshold). Extending sims... 40/100
#   > Suspicious (Real > Threshold). Extending sims... 60/100
#   > Suspicious (Real > Threshold). Extending sims... 80/100
# !!! Outlier: Real=21.4809 > P99=19.1981 (Sims: 100)
#   > Splitting cluster (Depth 2) - Size 54
#     > Initial Top Cols found: 165
#     > Split successful: 27 vs 27
#   > Sim Stop (Clean): Real=16.8411 < P99=31.5641 after 20 sims.
#   > Sim Stop (Clean): Real=16.8411 < P99=17.1143 after 20 sims.
#   > Sim Stop (Clean): Real=13.6928 < P99=25.5676 after 20 sims.
#   > Sim Stop (Clean): Real=13.5818 < P99=25.7751 after 20 sims.
#   > Sim Stop (Clean): Real=12.9247 < P99=21.2273 after 20 sims.
#   > Sim Stop (Clean): Real=14.4204 < P99=21.1700 after 20 sims.
#
# ========================================
# OPERATION                      | TIME (s)
# -------------------------------------------
# MI_Integrity_Check_Total       | 16.4594
# SPOA_alignment_initial         | 10.5299
# SPOA_alignment                 | 8.0027
# Sim_Parallel                   | 6.0540
# SPOA_Consensus_Total           | 2.8207
# Real_Score                     | 2.1226
# compute_mi_hybrid_execution    | 2.1204
# get_elbow_columns              | 0.4357
# ward_splitting                 | 0.1975
# Fuzzy_CDIST_Calculations       | 0.1541
# hamming_distance_matrix        | 0.1360
# encode_msa                     | 0.0851
# filter_consensus_generation    | 0.0299
# agglomerative_clustering       | 0.0166
# Filter_Invariant               | 0.0071
# ========================================
#
#      ID  cluster  mi_warning  barcodes_consistent  count
# 2  3634        0       False                 True     39
# 1  3134        1       False                 True     38
# 3  4134        2       False                 True     27
# 0   134        3       False                 True     27
# 4  4634        4       False                 True     36
# 5  5134        5       False                 True     37
#
#
# =============
# GCCCGTAGACGT
# Processing Top Barcode #17: GCCCGTAGACGT (Count: 176)
# length of filtered df: 196
#   > RapidFuzz gathered 196 reads
#   > Sim Stop (Clean): Real=15.6145 < P99=24.3132 after 20 sims.
#   > Suspicious (Real > Threshold). Extending sims... 20/100
#   > Suspicious (Real > Threshold). Extending sims... 40/100
#   > Suspicious (Real > Threshold). Extending sims... 60/100
#   > Suspicious (Real > Threshold). Extending sims... 80/100
# !!! Outlier: Real=55.0371 > P99=9.5061 (Sims: 100)
#   > Splitting cluster (Depth 0) - Size 128
#     > Initial Top Cols found: 359
#     > Split successful: 93 vs 35
#   > Suspicious (Real > Threshold). Extending sims... 20/100
#   > Suspicious (Real > Threshold). Extending sims... 40/100
#   > Suspicious (Real > Threshold). Extending sims... 60/100
#   > Suspicious (Real > Threshold). Extending sims... 80/100
# !!! Outlier: Real=59.3405 > P99=10.5254 (Sims: 100)
#   > Splitting cluster (Depth 1) - Size 93
#     > Initial Top Cols found: 282
#     > Split successful: 58 vs 35
#   > Suspicious (Real > Threshold). Extending sims... 20/100
#   > Suspicious (Real > Threshold). Extending sims... 40/100
#   > Suspicious (Real > Threshold). Extending sims... 60/100
#   > Suspicious (Real > Threshold). Extending sims... 80/100
# !!! Outlier: Real=61.1211 > P99=15.8402 (Sims: 100)
#   > Splitting cluster (Depth 2) - Size 58
#     > Initial Top Cols found: 198
#     > Split successful: 19 vs 39
#   > Sim Stop (Clean): Real=21.6192 < P99=26.9866 after 20 sims.
#   > Sim Stop (Clean): Real=12.9246 < P99=18.5570 after 20 sims.
#   > Sim Stop (Clean): Real=13.9741 < P99=20.4624 after 20 sims.
#   > Sim Stop (Clean): Real=13.9741 < P99=20.4675 after 20 sims.
#   > Sim Stop (Clean): Real=16.4970 < P99=24.5742 after 20 sims.
#
# ========================================
# OPERATION                      | TIME (s)
# -------------------------------------------
# MI_Integrity_Check_Total       | 17.5645
# SPOA_alignment_initial         | 11.3155
# SPOA_alignment                 | 8.6179
# Sim_Parallel                   | 6.4315
# ...
#   > Suspicious (Real > Threshold). Extending sims... 60/100
#   > Suspicious (Real > Threshold). Extending sims... 80/100
# !!! Outlier: Real=39.8826 > P99=18.6192 (Sims: 100)
#   > Splitting cluster (Depth 1) - Size 57
#     > Initial Top Cols found: 171
#     > Split successful: 39 vs 18
#   > Suspicious (Real > Threshold). Extending sims... 20/100
#   > Suspicious (Real > Threshold). Extending sims... 40/100
#   > Suspicious (Real > Threshold). Extending sims... 60/100
#   > Suspicious (Real > Threshold). Extending sims... 80/100
# !!! Outlier: Real=34.5486 > P99=24.7819 (Sims: 100)
#   > Splitting cluster (Depth 2) - Size 39
#     > Initial Top Cols found: 118
#     > Split successful: 24 vs 15
#   > Sim Stop (Clean): Real=18.3205 < P99=18.7085 after 20 sims.
#   > Sim Stop (Clean): Real=25.4930 < P99=45.2648 after 20 sims.
#   > Sim Stop (Clean): Real=22.4559 < P99=22.8034 after 20 sims.
#   > Sim Stop (Clean): Real=12.7350 < P99=24.3173 after 20 sims.
#
# ========================================
# OPERATION                      | TIME (s)
# -------------------------------------------
# MI_Integrity_Check_Total       | 148.4574
# SPOA_alignment_initial         | 107.3112
# SPOA_alignment                 | 81.3660
# Sim_Parallel                   | 49.6743
# SPOA_Consensus_Total           | 30.5661
# compute_mi_hybrid_execution    | 16.1121
# Real_Score                     | 15.4009
# get_elbow_columns              | 4.6959
# Fuzzy_CDIST_Calculations       | 1.8603
# ward_splitting                 | 1.7783
# hamming_distance_matrix        | 1.3187
# encode_msa                     | 0.9444
# filter_consensus_generation    | 0.3549
# agglomerative_clustering       | 0.1813
# Filter_Invariant               | 0.0770
# ========================================
#
#      ID  cluster  mi_warning  barcodes_consistent  count
# 2  3954        0       False                 True     33
# 1  3454        1       False                 True     26
# 5  5454        2       False                 True     24
# 0   454        3       False                 True     15
# 3  4454        4       False                 True     18
# 4  4954        5       False                 True     40
#
#
# =============
# CTTGTCGACTGT
# Processing Top Barcode #196: CTTGTCGACTGT (Count: 138)
# length of filtered df: 176
#   > RapidFuzz gathered 176 reads
#   > Suspicious (Real > Threshold). Extending sims... 20/100
#   > Suspicious (Real > Threshold). Extending sims... 40/100
#   > Suspicious (Real > Threshold). Extending sims... 60/100
#   > Suspicious (Real > Threshold). Extending sims... 80/100
# !!! Outlier: Real=54.4239 > P99=8.6870 (Sims: 100)
#   > Splitting cluster (Depth 0) - Size 118
#     > Initial Top Cols found: 295
#     > Split successful: 84 vs 34
#   > Suspicious (Real > Threshold). Extending sims... 20/100
#   > Suspicious (Real > Threshold). Extending sims... 40/100
#   > Suspicious (Real > Threshold). Extending sims... 60/100
#   > Suspicious (Real > Threshold). Extending sims... 80/100
# !!! Outlier: Real=35.8833 > P99=13.7952 (Sims: 100)
#   > Splitting cluster (Depth 1) - Size 84
#     > Initial Top Cols found: 238
#     > Split successful: 63 vs 21
#   > Sim Stop (Clean): Real=9.1710 < P99=16.6926 after 20 sims.
#   > Sim Stop (Clean): Real=20.1444 < P99=35.5564 after 20 sims.
#   > Sim Stop (Clean): Real=17.6660 < P99=26.6744 after 20 sims.
#   > Sim Stop (Clean): Real=15.2506 < P99=22.3672 after 20 sims.
#   > Sim Stop (Clean): Real=17.3024 < P99=17.4627 after 20 sims.
#
# ========================================
# OPERATION                      | TIME (s)
# -------------------------------------------
# MI_Integrity_Check_Total       | 149.1209
# SPOA_alignment_initial         | 107.8250
# SPOA_alignment                 | 81.7233
# Sim_Parallel                   | 49.9010
# SPOA_Consensus_Total           | 30.6878
# compute_mi_hybrid_execution    | 16.1916
# Real_Score                     | 15.4713
# get_elbow_columns              | 4.7208
# Fuzzy_CDIST_Calculations       | 1.8690
# ward_splitting                 | 1.7863
# hamming_distance_matrix        | 1.3251
# encode_msa                     | 0.9485
# filter_consensus_generation    | 0.3565
# agglomerative_clustering       | 0.1819
# Filter_Invariant               | 0.0774
# ========================================
#
#      ID  cluster  mi_warning  barcodes_consistent  count
# 1  3338        0       False                 True     31
# 2  3838        1       False                 True     26
# 3  4338        2       False                 True     32
# 0   338        2       False                 True     31
# 4  4838        3       False                 True     34
#
#
# =============
# TAACTCCCGTTT
# Processing Top Barcode #197: TAACTCCCGTTT (Count: 138)
# length of filtered df: 183
#   > RapidFuzz gathered 183 reads
#   > Sim Stop (Clean): Real=18.8845 < P99=24.8178 after 20 sims.
#   > Sim Stop (Clean): Real=12.9926 < P99=24.1065 after 20 sims.
#   > Suspicious (Real > Threshold). Extending sims... 20/100
#   > Suspicious (Real > Threshold). Extending sims... 40/100
#   > Suspicious (Real > Threshold). Extending sims... 60/100
#   > Suspicious (Real > Threshold). Extending sims... 80/100
# !!! Outlier: Real=57.9127 > P99=10.5252 (Sims: 100)
#   > Splitting cluster (Depth 0) - Size 121
#     > Initial Top Cols found: 303
#     > Split successful: 95 vs 26
#   > Suspicious (Real > Threshold). Extending sims... 20/100
#   > Suspicious (Real > Threshold). Extending sims... 40/100
#   > Suspicious (Real > Threshold). Extending sims... 60/100
#   > Suspicious (Real > Threshold). Extending sims... 80/100
# !!! Outlier: Real=61.1758 > P99=12.5764 (Sims: 100)
#   > Splitting cluster (Depth 1) - Size 95
#     > Initial Top Cols found: 252
#     > Split successful: 61 vs 34
#   > Suspicious (Real > Threshold). Extending sims... 20/100
#   > Suspicious (Real > Threshold). Extending sims... 40/100
#   > Suspicious (Real > Threshold). Extending sims... 60/100
#   > Suspicious (Real > Threshold). Extending sims... 80/100
# !!! Outlier: Real=64.0464 > P99=17.5350 (Sims: 100)
#   > Splitting cluster (Depth 2) - Size 61
#     > Initial Top Cols found: 166
#     > Split successful: 39 vs 22
#   > Sim Stop (Clean): Real=12.9247 < P99=24.0801 after 20 sims.
#   > Sim Stop (Clean): Real=19.4907 < P99=20.1621 after 20 sims.
#   > Sim Stop (Clean): Real=14.2691 < P99=26.6744 after 20 sims.
#   > Sim Stop (Clean): Real=17.3024 < P99=17.4627 after 20 sims.
#
# ========================================
# OPERATION                      | TIME (s)
# -------------------------------------------
# MI_Integrity_Check_Total       | 149.8970
# SPOA_alignment_initial         | 108.3878
# SPOA_alignment                 | 82.1323
# Sim_Parallel                   | 50.1772
# SPOA_Consensus_Total           | 30.8350
# compute_mi_hybrid_execution    | 16.2770
# Real_Score                     | 15.5514
# get_elbow_columns              | 4.7457
# Fuzzy_CDIST_Calculations       | 1.8775
# ward_splitting                 | 1.7966
# hamming_distance_matrix        | 1.3326
# encode_msa                     | 0.9532
# filter_consensus_generation    | 0.3585
# agglomerative_clustering       | 0.1826
# Filter_Invariant               | 0.0778
# ========================================
#
#      ID  cluster  mi_warning  barcodes_consistent  count
# 1  3369        0       False                 True     23
# 2  3869        1       False                 True     39
# 4  5369        2       False                 True     39
# 0   369        3       False                 True     22
# 3  4369        4       False                 True     34
#
#
# =============
# ATGTCCTCACCT
# Processing Top Barcode #198: ATGTCCTCACCT (Count: 137)
# length of filtered df: 154
#   > RapidFuzz gathered 154 reads
#   > Sim Stop (Clean): Real=12.7226 < P99=18.5580 after 20 sims.
#   > Sim Stop (Clean): Real=25.4930 < P99=45.0438 after 20 sims.
#   > Suspicious (Real > Threshold). Extending sims... 20/100
#   > Suspicious (Real > Threshold). Extending sims... 40/100
#   > Suspicious (Real > Threshold). Extending sims... 60/100
#   > Suspicious (Real > Threshold). Extending sims... 80/100
# !!! Outlier: Real=56.2666 > P99=12.1931 (Sims: 100)
#   > Splitting cluster (Depth 0) - Size 99
#     > Initial Top Cols found: 228
#     > Split successful: 77 vs 22
#   > Suspicious (Real > Threshold). Extending sims... 20/100
#   > Suspicious (Real > Threshold). Extending sims... 40/100
#   > Suspicious (Real > Threshold). Extending sims... 60/100
#   > Suspicious (Real > Threshold). Extending sims... 80/100
# !!! Outlier: Real=62.6908 > P99=14.7726 (Sims: 100)
#   > Splitting cluster (Depth 1) - Size 77
#     > Initial Top Cols found: 179
#     > Split successful: 49 vs 28
#   > Suspicious (Real > Threshold). Extending sims... 20/100
#   > Suspicious (Real > Threshold). Extending sims... 40/100
#   > Suspicious (Real > Threshold). Extending sims... 60/100
#   > Suspicious (Real > Threshold). Extending sims... 80/100
# !!! Outlier: Real=37.8942 > P99=20.8761 (Sims: 100)
#   > Splitting cluster (Depth 2) - Size 49
#     > Initial Top Cols found: 116
#     > Split successful: 26 vs 23
#   > Sim Stop (Clean): Real=17.3024 < P99=32.4378 after 20 sims.
#   > Sim Stop (Clean): Real=18.8845 < P99=19.2678 after 20 sims.
#   > Sim Stop (Clean): Real=16.4076 < P99=28.8339 after 20 sims.
#   > Sim Stop (Clean): Real=19.4907 < P99=35.0037 after 20 sims.
#
# ========================================
# OPERATION                      | TIME (s)
# -------------------------------------------
# MI_Integrity_Check_Total       | 150.4242
# SPOA_alignment_initial         | 108.8191
# SPOA_alignment                 | 82.4307
# Sim_Parallel                   | 50.3480
# SPOA_Consensus_Total           | 30.9737
# compute_mi_hybrid_execution    | 16.3409
# Real_Score                     | 15.6026
# get_elbow_columns              | 4.7665
# Fuzzy_CDIST_Calculations       | 1.8863
# ward_splitting                 | 1.8020
# hamming_distance_matrix        | 1.3373
# encode_msa                     | 0.9572
# filter_consensus_generation    | 0.3601
# agglomerative_clustering       | 0.1832
# Filter_Invariant               | 0.0782
# ========================================
#
#      ID  cluster  mi_warning  barcodes_consistent  count
# 1  3358        0       False                 True     40
# 2  3858        1       False                 True     15
# 4  4858        2       False                 True     26
# 0   358        3       False                 True     23
# 5  5358        4       False                 True     28
# 3  4358        5       False                 True     22
#
#
# =============
# CCGTCAAAGGCT
# Processing Top Barcode #199: CCGTCAAAGGCT (Count: 137)
# length of filtered df: 178
#   > RapidFuzz gathered 178 reads
#   > Suspicious (Real > Threshold). Extending sims... 20/100
#   > Suspicious (Real > Threshold). Extending sims... 40/100
#   > Suspicious (Real > Threshold). Extending sims... 60/100
#   > Suspicious (Real > Threshold). Extending sims... 80/100
# !!! Outlier: Real=49.9388 > P99=10.3438 (Sims: 100)
#   > Splitting cluster (Depth 0) - Size 123
#     > Initial Top Cols found: 362
#     > Split successful: 99 vs 24
#   > Suspicious (Real > Threshold). Extending sims... 20/100
#   > Suspicious (Real > Threshold). Extending sims... 40/100
#   > Suspicious (Real > Threshold). Extending sims... 60/100
#   > Suspicious (Real > Threshold). Extending sims... 80/100
# !!! Outlier: Real=54.9320 > P99=11.2558 (Sims: 100)
#   > Splitting cluster (Depth 1) - Size 99
#     > Initial Top Cols found: 306
#     > Split successful: 72 vs 27
#   > Suspicious (Real > Threshold). Extending sims... 20/100
#   > Suspicious (Real > Threshold). Extending sims... 40/100
#   > Suspicious (Real > Threshold). Extending sims... 60/100
#   > Suspicious (Real > Threshold). Extending sims... 80/100
# !!! Outlier: Real=35.1393 > P99=11.9325 (Sims: 100)
#   > Splitting cluster (Depth 2) - Size 72
#     > Initial Top Cols found: 250
#     > Split successful: 39 vs 33
#   > Sim Stop (Clean): Real=12.9577 < P99=18.4646 after 20 sims.
#   > Sim Stop (Clean): Real=14.6772 < P99=23.8632 after 20 sims.
#   > Sim Stop (Clean): Real=16.8411 < P99=25.4861 after 20 sims.
#   > Sim Stop (Clean): Real=18.5100 < P99=28.5861 after 20 sims.
#   > Sim Stop (Clean): Real=13.1691 < P99=23.6010 after 20 sims.
#   > Sim Stop (Clean): Real=23.3718 < P99=23.7643 after 20 sims.
#
# ========================================
# OPERATION                      | TIME (s)
# -------------------------------------------
# MI_Integrity_Check_Total       | 151.5414
# SPOA_alignment_initial         | 109.5563
# SPOA_alignment                 | 83.0169
# Sim_Parallel                   | 50.7601
# SPOA_Consensus_Total           | 31.1065
# compute_mi_hybrid_execution    | 16.4485
# Real_Score                     | 15.7088
# get_elbow_columns              | 4.7950
# Fuzzy_CDIST_Calculations       | 1.8947
# ward_splitting                 | 1.8158
# hamming_distance_matrix        | 1.3446
# encode_msa                     | 0.9624
# filter_consensus_generation    | 0.3618
# agglomerative_clustering       | 0.1839
# Filter_Invariant               | 0.0789
# ========================================
#
#      ID  cluster  mi_warning  barcodes_consistent  count
# 2  3527        0       False                 True     38
# 1  3027        1       False                 True     17
# 0    27        2       False                 True     39
# 3  4027        3       False                 True     33
# 4  4527        4       False                 True     24
#
#
# =============
# GTAAGATGTGTG
# Processing Top Barcode #200: GTAAGATGTGTG (Count: 137)
# length of filtered df: 164
#   > RapidFuzz gathered 164 reads
#   > Suspicious (Real > Threshold). Extending sims... 20/100
#   > Suspicious (Real > Threshold). Extending sims... 40/100
#   > Suspicious (Real > Threshold). Extending sims... 60/100
#   > Suspicious (Real > Threshold). Extending sims... 80/100
# !!! Outlier: Real=58.7218 > P99=9.8330 (Sims: 100)
#   > Splitting cluster (Depth 0) - Size 121
#     > Initial Top Cols found: 311
#     > Split successful: 82 vs 39
#   > Suspicious (Real > Threshold). Extending sims... 20/100
#   > Suspicious (Real > Threshold). Extending sims... 40/100
#   > Suspicious (Real > Threshold). Extending sims... 60/100
#   > Suspicious (Real > Threshold). Extending sims... 80/100
# !!! Outlier: Real=62.3209 > P99=14.0569 (Sims: 100)
#   > Splitting cluster (Depth 1) - Size 82
#     > Initial Top Cols found: 246
#     > Split successful: 66 vs 16
#   > Suspicious (Real > Threshold). Extending sims... 20/100
#   > Suspicious (Real > Threshold). Extending sims... 40/100
#   > Suspicious (Real > Threshold). Extending sims... 60/100
#   > Suspicious (Real > Threshold). Extending sims... 80/100
# !!! Outlier: Real=65.0360 > P99=16.5721 (Sims: 100)
#   > Splitting cluster (Depth 2) - Size 66
#     > Initial Top Cols found: 201
#     > Split successful: 34 vs 32
#   > Sim Stop (Clean): Real=14.3454 < P99=27.4491 after 20 sims.
#   > Sim Stop (Clean): Real=14.9061 < P99=24.3792 after 20 sims.
#   > Sim Stop (Clean): Real=24.3792 < P99=24.8260 after 20 sims.
#   > Sim Stop (Clean): Real=16.2329 < P99=24.7819 after 20 sims.
#   > Sim Stop (Clean): Real=24.3792 < P99=36.0453 after 20 sims.
#   > Sim Stop (Clean): Real=16.7712 < P99=21.6354 after 20 sims.
#
# ========================================
# OPERATION                      | TIME (s)
# -------------------------------------------
# MI_Integrity_Check_Total       | 152.4194
# SPOA_alignment_initial         | 110.1126
# SPOA_alignment                 | 83.4498
# Sim_Parallel                   | 51.1160
# SPOA_Consensus_Total           | 31.2691
# compute_mi_hybrid_execution    | 16.5618
# Real_Score                     | 15.7883
# get_elbow_columns              | 4.8184
# Fuzzy_CDIST_Calculations       | 1.9031
# ward_splitting                 | 1.8259
# hamming_distance_matrix        | 1.3502
# encode_msa                     | 0.9667
# filter_consensus_generation    | 0.3635
# agglomerative_clustering       | 0.1846
# Filter_Invariant               | 0.0794
# ========================================
#
#      ID  cluster  mi_warning  barcodes_consistent  count
# 2  3977        0       False                 True     16
# 1  3477        1       False                 True     27
# 3  4477        2       False                 True     34
# 0   477        3       False                 True     32
# 4  5477        4       False                 True     39

# %%
print(result_df2)
