# %%
import numpy as np
import pandas as pd
import random
import time
from scipy.sparse import coo_matrix
from scipy.sparse.csgraph import connected_components
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.decomposition import TruncatedSVD
from sklearn.preprocessing import Normalizer

# --- 1. DATA GENERATION ---
print("--- Generating Data ---")
random.seed(42)
np.random.seed(42)

def mutate_sequence(seq, error_rate=0.10):
    if error_rate <= 0: return seq
    seq_list = list(seq)
    new_seq = []
    for base in seq_list:
        if random.random() < error_rate:
            r = random.random()
            if r < 0.5: new_seq.append(random.choice("ACGT")) 
            elif r < 0.75: 
                new_seq.append(base)
                new_seq.append(random.choice("ACGT"))
            else: pass 
        else:
            new_seq.append(base)
    return "".join(new_seq)

def gen_dna(k): return "".join(random.choices("ACGT", k=k))

# Using a smaller set to verify the fix quickly
n_items = 2000 
pool_bc = [gen_dna(10) for _ in range(n_items)]
pool_ins = [gen_dna(150) for _ in range(n_items)]

data = []
for i in range(n_items):
    n_reads = random.randint(3, 30) # Ensure most clusters have peers
    for _ in range(n_reads):
        data.append({
            "ID": i,
            "Barcode": mutate_sequence(pool_bc[i], 0.05), 
            "Insert": mutate_sequence(pool_ins[i], 0.05)
        })

df = pd.DataFrame(data)
print(f"Dataset: {len(df)} reads (Target Clusters: {n_items})")



# Pick a random barcode


# > from rapidfuzz import process, fuzz
# > choices = ["Atlanta Falcons", "New York Jets", "New York Giants", "Dallas Cowboys"]
# > process.extract("new york jets", choices, scorer=fuzz.WRatio, limit=2)
# Out:
# --- Generating Data ---
# Dataset: 32991 reads (Target Clusters: 2000)

# %%
from rapidfuzz import process, fuzz
import numpy as np

barcode_counts = df['Barcode'].value_counts()

all_barcodes = np.array(barcode_counts.index.tolist())

for barcode, count in barcode_counts.items():
    print(f"Barcode: {barcode} | Count: {count}")

    # get distance from other bcs using rapid fuzz

    scores = [fuzz.ratio(barcode, bc) for bc in all_barcodes]
    
    # Assuming 'scores' is the list containing your similarity ratios
    indices_in_range = [i for i, score in enumerate(scores) if 80 < score < 100]

    print(all_barcodes[indices_in_range])

    # Example: Stop after the top 10 for quick review
    if count < barcode_counts.head(5).iloc[-1]: 
        break
# Out:
# Barcode: CTGAGGCTCA | Count: 24
# ['CTGTAGCCA' 'CTGAGGGTCA' 'CTGCAGGCTCA' 'CTGAGGCTCTA' 'CTGAGGATCA'
#  'CTGAGGGCTCA' 'CTAGGACTA' 'CTGAGTCAT' 'CTGTAGCTCA' 'TGTAGCTCA'
#  'TGAGATCGCTCA' 'CATGAGGCT' 'CTGCGGTCA' 'CTTGAGGTA' 'CTGACGGTC']
# Barcode: ATACTTGAGG | Count: 23
# ['TACTTACGG' 'ATACTTGAGC' 'ATCTTCAGG' 'ATACTTGACG' 'ATACGTGAGG'
#  'TACTTGAGG' 'AACTTGGGT' 'GATATTGAGGA' 'ATTACTGAG' 'ATGACTTGAG'
#  'TACTGTGAG' 'ATTACTGAGAG' 'ATACGAGAG' 'ATACGCAGG' 'TACTTTGAGGAC']
# Barcode: CCATCTGATT | Count: 23
# ['CCACTGTTT' 'CCATACATT' 'CCTATCGATTG' 'CCACGATTG' 'CCAGTCGATT' 'CCATCTTT'
#  'CCAGTCGTT' 'CAGTCTGCATT' 'CTCTGTATT' 'CCTGCTGAT' 'CAGCATCTGAT'
#  'CGCATCTGT' 'CCACGATTC' 'CCATCGGTT' 'CACATCGTT' 'CCATCAGTT' 'CCATCTTATT'
#  'CCTCTGATT' 'CCATCTGATA' 'GCATCTGAT' 'CATCTGACTT' 'CCATTCTGATT'
#  'CATCTGATT' 'CAGTCGATT' 'CCACTGGTT' 'GCCTCTGTT' 'CCATCTGAG']
# Barcode: GTATGTCCAT | Count: 23
# ['GTTATGTCCTTT' 'GTTTCCGAT' 'GTTTACCAT' 'TGTTATGCCAT' 'GTATGTCATCT'
#  'CTGTAGTCCAT' 'GTATGTGCC' 'GTATATCAT' 'GTATGGTCCAT' 'GTATGTACAT'
#  'GGATGTCCATT' 'GTATGTCCAC' 'GTATGCTCCACT' 'GGATGTCCAT' 'GTACGCCAT'
#  'CGATAGTCCAT' 'CTTGTCCAT' 'GTTGTCCTC' 'GATGTCATA' 'GTTTGTCCT']
# Barcode: TGGAATGTCG | Count: 23
# ['GGCAATGTCG' 'TGGAACTGCG' 'TAATGTACG' 'TAATGATCG' 'TGGAACTGACG'
#  'TGGAACTGG' 'GGAAGTCCG' 'TGGACATGTCG' 'TGGAAGTCG' 'TGAGAATGTCG'
#  'TGGAATGTCA' 'TAGGAATGTCG' 'TGGAATGTC' 'TGTAATGTCGC' 'TGGATCGCG'
#  'TGTCGATGTCG' 'TGAGCATGTCG' 'GGAATGTCG' 'GGCATGTCG' 'GGCAAGTCG'
#  'GGCAATGTTCG' 'GGCAATCGTCG' 'ATGGAATTCGT' 'TGATATGTCGG']
# Barcode: CGGCGAGTAG | Count: 23
# ['GGACGAGTAG' 'CGGCGAGATA' 'CGGGCGAGA' 'CGGCGGTCA' 'GGCACGTAG' 'GGCAAGTAG'
#  'CGCGCGATA' 'GACGAGTAG' 'GGTACGAGTAG' 'GGACGAGTAGG' 'GGACGAGAG'
#  'GGCGACGAG' 'CGGCGGATA' 'CGGCGACGATA' 'CGGCGAGCTA' 'CGCGAGATA'
#  'CGGCGTAGATA' 'CGCGCATAG' 'CTGGCGAGA' 'CTGGCGAGTAG' 'CGGCGAGGTAC'
#  'CGGCGGTAG' 'CGCCGAGTAG' 'CGGCGAGTTG' 'CGGTGAGTAG' 'CGGCGAATAGT'
#  'CGGCGGTTAG' 'CGGCGGTTA' 'CGGTCGGTG']
# Barcode: CATTTTTAAC | Count: 23
# ['ATTGTTTAA' 'CGACTTTTTAC' 'TTTTTAACA' 'ACATTTTAGAC' 'AATTTTTAGAC'
#  'CATTTTGTAC' 'CATTTTGAGAC' 'CATTTTTAACT' 'TATTTTTAAC' 'CATTTTAAC'
#  'CTTTTTAAC' 'CACTTTTAAC' 'CGATTTTTAAC' 'CTATTTTTAAC']
# Barcode: AACCTACAGT | Count: 22
# ['AACCACTAGTG' 'AACCGACGT' 'AACCTCAGAT' 'AATCACAGT' 'AACCACAGG'
#  'AACCTACACT' 'AACCTTCAGT' 'AACCGACAGT' 'AACCTCAGT' 'AACCTACAGC'
#  'AACCTAAGTA' 'AACCTCTAGTG' 'ACCTCAGTG' 'AACTCTCAG' 'AAGCTAAGT'
#  'ACTACAGTC' 'AACCTCAGCTA' 'AACTCAGTA' 'ACCTATCAG' 'GAACTCAGT' 'ACCTAGCAG']
